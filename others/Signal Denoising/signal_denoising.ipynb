# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# ## Create signals

# %%
freq = 1
ampl = 1
phi = 0

# %%
# datapoints
x = np.linspace(0, 50, 300)
#x = np.linspace(-np.pi, np.pi, 201)
y = ampl * np.sin(freq * x - phi)

# %%
# creat noise
np.random.seed(10)
noise = np.random.uniform(-0.3, 0.3, size = x.shape[0])
y_noisy = y + noise

# %% [markdown]
# ## plot the clean and noisy signal

# %%
fig, ax = plt.subplots(1, 3, figsize = (12, 4))
ax[0].set_title('Sine')
ax[0].plot(x, y)
ax[1].set_title('Noise')
ax[1].plot(x, noise)
ax[2].set_title('Sine + Noise')
ax[2].plot(x, y_noisy, 'r')

# %% [markdown]
# ## create n_sample by sample_len, both clean and noisy

# %%
n_samples = 100
sample_len = 400

clean_sig = np.zeros((n_samples, sample_len))
noisy_sig = np.zeros((n_samples, sample_len))

for i in range (n_samples):  # i=0
    
    rand = np.random.uniform (0, 1)
    freq = 1+rand
    ampl = 1 + np.random.uniform (0, 1)
    #phi = 0 + np.random.uniform (0, 5)
    
    x = np.linspace(0, 50, sample_len)
    x = x + np.random.uniform (-10, 10)
    
    clean_sig [i, :] = ampl * np.sin(freq * x)
    noisy_sig [i, :] = clean_sig [i, :] + np.random.uniform (-0.4, 0.4, size=len(x))

# %% [markdown]
# ## plot the clean and noisy signal

# %%
sample = 80
fig, ax = plt.subplots(1, 2, figsize = (12, 4))
# ax[0].set_title('Sine')
ax[0].plot(x, clean_sig[sample, :])
ax[1].plot(x, noisy_sig[sample, :], 'r')

# %%
noisy_signals = noisy_sig.copy()
clean_signals = clean_sig.copy()

# %%
noisy_signals.shape
# Out:
# (100, 400)

# %% [markdown]
# ## reshape (sample, length, featuers)

# %%
noisy_signals = noisy_signals.reshape(noisy_signals.shape[0],noisy_signals.shape[1],1)
clean_signals = clean_signals.reshape(clean_signals.shape[0],clean_signals.shape[1],1)

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
#-- randomly assign the train and test set, useing sklearn
x_train, x_test, y_train, y_test = train_test_split(
    noisy_signals, clean_signals, test_size=0.15)

# %%
#-- Plot a sample signal
ind=2
fig, ax = plt.subplots()
plt.plot (x_test[ind,:], label="Noisy")
plt.plot (y_test[ind,:], label="Clean")
plt.title('Training data noisy&clean')
plt.legend()
plt.show()

# %% [markdown]
# ## Importing the Keras libraries and packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU
from tensorflow.keras.layers import RepeatVector, TimeDistributed, Bidirectional

# %% [markdown]
# ## define model

# %%
timesteps = x_train.shape[1]
No_of_features = x_train.shape[2]
No_epoch=10 
batch_size = 5

# %%
rnn_model = Sequential()
rnn_model.add(Bidirectional(GRU(units = 100, return_sequences = True,
                    activation='relu', input_shape = (timesteps, No_of_features))))

rnn_model.add(GRU(10, activation='relu', return_sequences=True))

#rnn_model.add(RepeatVector(timesteps))

rnn_model.add(GRU(10, activation='relu', return_sequences=True))
rnn_model.add(GRU(100, activation='relu', return_sequences=True))
rnn_model.add(TimeDistributed(Dense(1)))
#rnn_model.add(Dense(units = 1, activation='relu'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20696/1739258025.py in <module>
# ----> 1 rnn_model = Sequential()
#       2 rnn_model.add(Bidirectional(GRU(units = 100, return_sequences = True,
#       3                     activation='relu', input_shape = (timesteps, No_of_features))))
#       4
#       5 rnn_model.add(GRU(10, activation='relu', return_sequences=True))
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\keras\engine\sequential.py in __init__(self, layers, name)
#     107     """
#     108     # Skip the init in FunctionalModel since model doesn't have input/output yet
# --> 109     super(functional.Functional, self).__init__(  # pylint: disable=bad-super-call
#     110         name=name, autocast=False)
#     111     base_layer.keras_api_gauge.get_cell('Sequential').set(True)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\keras\engine\training.py in __init__(self, *args, **kwargs)
#     279     self._steps_per_execution = None
#     280
# --> 281     self._init_batch_counters()
#     282     self._base_model_initialized = True
#     283
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\keras\engine\training.py in _init_batch_counters(self)
#     287     # `evaluate`, and `predict`.
#     288     agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
# --> 289     self._train_counter = tf.Variable(0, dtype='int64', aggregation=agg)
#     290     self._test_counter = tf.Variable(0, dtype='int64', aggregation=agg)
#     291     self._predict_counter = tf.Variable(
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     268       return cls._variable_v1_call(*args, **kwargs)
#     269     elif cls is Variable:
# --> 270       return cls._variable_v2_call(*args, **kwargs)
#     271     else:
#     272       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     249     if aggregation is None:
#     250       aggregation = VariableAggregation.NONE
# --> 251     return previous_getter(
#     252         initial_value=initial_value,
#     253         trainable=trainable,
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kws)
#     242                         shape=None):
#     243     """Call on Variable class. Useful to force the signature."""
# --> 244     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     245     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     246       previous_getter = _make_getter(getter, previous_getter)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator_v2(next_creator, **kwargs)
#    2660   shape = kwargs.get("shape", None)
#    2661
# -> 2662   return resource_variable_ops.ResourceVariable(
#    2663       initial_value=initial_value,
#    2664       trainable=trainable,
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     270       return cls._variable_v2_call(*args, **kwargs)
#     271     else:
# --> 272       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     273
#     274
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1628       self._init_from_proto(variable_def, import_scope=import_scope)
#    1629     else:
# -> 1630       self._init_from_args(
#    1631           initial_value=initial_value,
#    1632           trainable=trainable,
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1779               self._update_uid = initial_value.checkpoint_position.restore_uid
#    1780               initial_value = initial_value.wrapped_value
# -> 1781             initial_value = ops.convert_to_tensor(initial_value,
#    1782                                                   name="initial_value",
#    1783                                                   dtype=dtype)
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1619
#    1620     if ret is None:
# -> 1621       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1622
#    1623     if ret is NotImplemented:
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     103     except AttributeError:
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# --> 105   ctx.ensure_initialized()
#     106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#
# D:\Anaconda\envs\adv_maths\lib\site-packages\tensorflow\python\eager\context.py in ensure_initialized(self)
#     569         pywrap_tfe.TFE_ContextOptionsSetRunEagerOpAsFunction(
#     570             opts, self._run_eager_op_as_function)
# --> 571         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     572       finally:
#     573         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# KeyboardInterrupt:

# %%
rnn_model.compile(optimizer='adam', loss='mean_absolute_error')

# %%
rnn_model.summary()

# %%
rnn_model.fit(x_train, y_train, epochs = No_epoch, 
              batch_size = batch_size)

# %% [markdown]
# ## Predictions

# %%
#-- Predict the output for test set
x_test_pred = rnn_model.predict(x_test, verbose=1)

# %%
#-- save the RNN model to be used later----------------------------------------
from keras.models import load_model
model_name = "LSTM_Auto_sine.h5"
# rnn_model.save(model_name)

# %%
#-- Load the model
rnn_model2 = load_model(model_name)
# Out:
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
x_test_pred = rnn_model2.predict(x_test, verbose=1)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
#-- plot the test results--------------
ind = 0
fig, ax = plt.subplots()

# plt.plot (x_test[ind,:,0], label="Noisy")
# plt.plot (x_test_pred[ind,:,0], color='g', linewidth=2,  label="Pred")
plt.plot (y_test[ind,], color = "orange", linestyle=':', linewidth=1.5,\
          label="True Ind.")

plt.legend()
plt.xlabel ("Circumferential Locations (Degrees)")
plt.ylabel ("Distance (mm)")
plt.show()

# %%
#plt.savefig("x_test"+str(ind)+".tif", dpi=200, format='tif')

# %% [markdown]
# ## Are there any chances of improvement?

# %%
# define model
model = Sequential()
model.add(Bidirectional(LSTM(units = 128, return_sequences = True,
                    activation='tanh', input_shape = (timesteps, No_of_features))))

model.add(LSTM(64, activation='tanh', return_sequences=True))

model.add(LSTM(16, activation='tanh', return_sequences=True))

#model.add(RepeatVector(timesteps))

model.add(LSTM(16, activation='tanh', return_sequences=True))

model.add(LSTM(64, activation='tanh', return_sequences=True))

model.add(LSTM(128, activation='tanh', return_sequences=True))

model.add(TimeDistributed(Dense(1)))
#rnn_model.add(Dense(units = 1, activation='relu'))

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x_train, y_train, epochs = 1000, 
              batch_size = 16, verbose=2)
# Out:
# Epoch 1/1000
# 6/6 - 9s - loss: 1.0252 - 9s/epoch - 2s/step
# Epoch 2/1000
# 6/6 - 1s - loss: 0.4540 - 953ms/epoch - 159ms/step
# Epoch 3/1000
# 6/6 - 1s - loss: 0.2735 - 1s/epoch - 167ms/step
# Epoch 4/1000
# 6/6 - 1s - loss: 0.1830 - 1s/epoch - 171ms/step
# Epoch 5/1000
# 6/6 - 1s - loss: 0.1246 - 998ms/epoch - 166ms/step
# Epoch 6/1000
# 6/6 - 1s - loss: 0.1020 - 996ms/epoch - 166ms/step
# Epoch 7/1000
# 6/6 - 1s - loss: 0.0861 - 949ms/epoch - 158ms/step
# Epoch 8/1000
# 6/6 - 1s - loss: 0.0846 - 946ms/epoch - 158ms/step
# Epoch 9/1000
# 6/6 - 1s - loss: 0.0689 - 958ms/epoch - 160ms/step
# Epoch 10/1000
# 6/6 - 1s - loss: 0.0654 - 995ms/epoch - 166ms/step
# Epoch 11/1000
# 6/6 - 1s - loss: 0.0631 - 1s/epoch - 173ms/step
# Epoch 12/1000
# 6/6 - 1s - loss: 0.0574 - 1s/epoch - 171ms/step
# Epoch 13/1000
# 6/6 - 1s - loss: 0.0552 - 944ms/epoch - 157ms/step
# Epoch 14/1000
# 6/6 - 1s - loss: 0.0474 - 998ms/epoch - 166ms/step
# Epoch 15/1000
# 6/6 - 1s - loss: 0.0445 - 992ms/epoch - 165ms/step
# Epoch 16/1000
# 6/6 - 1s - loss: 0.0402 - 1s/epoch - 174ms/step
# Epoch 17/1000
# 6/6 - 1s - loss: 0.0416 - 1s/epoch - 168ms/step
# Epoch 18/1000
# 6/6 - 1s - loss: 0.0344 - 1s/epoch - 173ms/step
# Epoch 19/1000
# 6/6 - 1s - loss: 0.0307 - 1s/epoch - 168ms/step
# Epoch 20/1000
# 6/6 - 1s - loss: 0.0289 - 996ms/epoch - 166ms/step
# Epoch 21/1000
# 6/6 - 1s - loss: 0.0274 - 938ms/epoch - 156ms/step
# Epoch 22/1000
# 6/6 - 1s - loss: 0.0266 - 1s/epoch - 168ms/step
# Epoch 23/1000
# 6/6 - 1s - loss: 0.0256 - 1s/epoch - 172ms/step
# Epoch 24/1000
# 6/6 - 1s - loss: 0.0250 - 1s/epoch - 167ms/step
# Epoch 25/1000
# 6/6 - 1s - loss: 0.0246 - 1s/epoch - 170ms/step
# Epoch 26/1000
# 6/6 - 1s - loss: 0.0245 - 1s/epoch - 175ms/step
# Epoch 27/1000
# 6/6 - 1s - loss: 0.0238 - 946ms/epoch - 158ms/step
# Epoch 28/1000
# 6/6 - 1s - loss: 0.0237 - 1s/epoch - 173ms/step
# Epoch 29/1000
# 6/6 - 1s - loss: 0.0232 - 978ms/epoch - 163ms/step
# Epoch 30/1000
# 6/6 - 1s - loss: 0.0230 - 1s/epoch - 174ms/step
# Epoch 31/1000
# 6/6 - 1s - loss: 0.0230 - 903ms/epoch - 150ms/step
# Epoch 32/1000
# 6/6 - 1s - loss: 0.0235 - 1s/epoch - 177ms/step
# Epoch 33/1000
# 6/6 - 1s - loss: 0.0220 - 1s/epoch - 178ms/step
# Epoch 34/1000
# 6/6 - 1s - loss: 0.0214 - 1s/epoch - 179ms/step
# Epoch 35/1000
# 6/6 - 1s - loss: 0.0215 - 1s/epoch - 175ms/step
# Epoch 36/1000
# 6/6 - 1s - loss: 0.0210 - 1s/epoch - 170ms/step
# Epoch 37/1000
# 6/6 - 1s - loss: 0.0202 - 1s/epoch - 169ms/step
# Epoch 38/1000
# 6/6 - 1s - loss: 0.0205 - 1s/epoch - 168ms/step
# Epoch 39/1000
# 6/6 - 1s - loss: 0.0206 - 1s/epoch - 175ms/step
# Epoch 40/1000
# 6/6 - 1s - loss: 0.0200 - 1s/epoch - 171ms/step
# Epoch 41/1000
# 6/6 - 1s - loss: 0.0192 - 950ms/epoch - 158ms/step
# Epoch 42/1000
# 6/6 - 1s - loss: 0.0187 - 929ms/epoch - 155ms/step
# Epoch 43/1000
# 6/6 - 1s - loss: 0.0186 - 1s/epoch - 177ms/step
# Epoch 44/1000
# 6/6 - 1s - loss: 0.0187 - 1s/epoch - 170ms/step
# Epoch 45/1000
# 6/6 - 1s - loss: 0.0187 - 1s/epoch - 171ms/step
# Epoch 46/1000
# 6/6 - 1s - loss: 0.0182 - 1s/epoch - 172ms/step
# Epoch 47/1000
# 6/6 - 1s - loss: 0.0182 - 989ms/epoch - 165ms/step
# Epoch 48/1000
# 6/6 - 1s - loss: 0.0176 - 967ms/epoch - 161ms/step
# Epoch 49/1000
# 6/6 - 1s - loss: 0.0172 - 1s/epoch - 171ms/step
# Epoch 50/1000
# 6/6 - 1s - loss: 0.0169 - 996ms/epoch - 166ms/step
# Epoch 51/1000
# 6/6 - 1s - loss: 0.0168 - 1s/epoch - 176ms/step
# Epoch 52/1000
# 6/6 - 1s - loss: 0.0173 - 904ms/epoch - 151ms/step
# Epoch 53/1000
# 6/6 - 1s - loss: 0.0172 - 945ms/epoch - 157ms/step
# Epoch 54/1000
# 6/6 - 1s - loss: 0.0168 - 1s/epoch - 175ms/step
# Epoch 55/1000
# 6/6 - 1s - loss: 0.0167 - 1s/epoch - 177ms/step
# Epoch 56/1000
# 6/6 - 1s - loss: 0.0173 - 941ms/epoch - 157ms/step
# Epoch 57/1000
# 6/6 - 1s - loss: 0.0167 - 940ms/epoch - 157ms/step
# Epoch 58/1000
# 6/6 - 1s - loss: 0.0167 - 1s/epoch - 173ms/step
# Epoch 59/1000
# 6/6 - 1s - loss: 0.0164 - 980ms/epoch - 163ms/step
# Epoch 60/1000
# 6/6 - 1s - loss: 0.0161 - 1s/epoch - 173ms/step
# Epoch 61/1000
# 6/6 - 1s - loss: 0.0159 - 1s/epoch - 170ms/step
# Epoch 62/1000
# 6/6 - 1s - loss: 0.0155 - 985ms/epoch - 164ms/step
# Epoch 63/1000
# 6/6 - 1s - loss: 0.0155 - 1s/epoch - 172ms/step
# Epoch 64/1000
# 6/6 - 1s - loss: 0.0160 - 951ms/epoch - 159ms/step
# Epoch 65/1000
# 6/6 - 1s - loss: 0.0159 - 982ms/epoch - 164ms/step
# Epoch 66/1000
# 6/6 - 1s - loss: 0.0155 - 973ms/epoch - 162ms/step
# Epoch 67/1000
# 6/6 - 1s - loss: 0.0150 - 996ms/epoch - 166ms/step
# Epoch 68/1000
# 6/6 - 1s - loss: 0.0158 - 1s/epoch - 175ms/step
# Epoch 69/1000
# 6/6 - 1s - loss: 0.0163 - 1s/epoch - 167ms/step
# Epoch 70/1000
# 6/6 - 1s - loss: 0.0152 - 952ms/epoch - 159ms/step
# Epoch 71/1000
# 6/6 - 1s - loss: 0.0145 - 978ms/epoch - 163ms/step
# Epoch 72/1000
# 6/6 - 1s - loss: 0.0147 - 1s/epoch - 167ms/step
# Epoch 73/1000
# 6/6 - 1s - loss: 0.0146 - 1s/epoch - 167ms/step
# Epoch 74/1000
# 6/6 - 1s - loss: 0.0144 - 1s/epoch - 169ms/step
# Epoch 75/1000
# 6/6 - 1s - loss: 0.0137 - 1s/epoch - 170ms/step
# Epoch 76/1000
# 6/6 - 1s - loss: 0.0140 - 988ms/epoch - 165ms/step
# Epoch 77/1000
# 6/6 - 1s - loss: 0.0138 - 1s/epoch - 169ms/step
# Epoch 78/1000
# 6/6 - 1s - loss: 0.0134 - 1s/epoch - 169ms/step
# Epoch 79/1000
# 6/6 - 1s - loss: 0.0133 - 964ms/epoch - 161ms/step
# Epoch 80/1000
# 6/6 - 1s - loss: 0.0136 - 904ms/epoch - 151ms/step
# Epoch 81/1000
# 6/6 - 1s - loss: 0.0138 - 1s/epoch - 171ms/step
# Epoch 82/1000
# 6/6 - 1s - loss: 0.0145 - 1000ms/epoch - 167ms/step
# Epoch 83/1000
# 6/6 - 1s - loss: 0.0134 - 993ms/epoch - 165ms/step
# Epoch 84/1000
# 6/6 - 1s - loss: 0.0139 - 984ms/epoch - 164ms/step
# Epoch 85/1000
# 6/6 - 1s - loss: 0.0136 - 1s/epoch - 171ms/step
# Epoch 86/1000
# 6/6 - 1s - loss: 0.0131 - 1s/epoch - 172ms/step
# Epoch 87/1000
# 6/6 - 1s - loss: 0.0131 - 1s/epoch - 173ms/step
# Epoch 88/1000
# 6/6 - 1s - loss: 0.0125 - 974ms/epoch - 162ms/step
# Epoch 89/1000
# 6/6 - 1s - loss: 0.0124 - 1s/epoch - 176ms/step
# Epoch 90/1000
# 6/6 - 1s - loss: 0.0123 - 893ms/epoch - 149ms/step
# Epoch 91/1000
# 6/6 - 1s - loss: 0.0122 - 937ms/epoch - 156ms/step
# Epoch 92/1000
# 6/6 - 1s - loss: 0.0122 - 1s/epoch - 171ms/step
# Epoch 93/1000
# 6/6 - 1s - loss: 0.0121 - 1s/epoch - 173ms/step
# Epoch 94/1000
# 6/6 - 1s - loss: 0.0126 - 1s/epoch - 167ms/step
# Epoch 95/1000
# 6/6 - 1s - loss: 0.0122 - 1s/epoch - 167ms/step
# Epoch 96/1000
# 6/6 - 1s - loss: 0.0124 - 954ms/epoch - 159ms/step
# Epoch 97/1000
# 6/6 - 1s - loss: 0.0123 - 1s/epoch - 171ms/step
# Epoch 98/1000
# 6/6 - 1s - loss: 0.0120 - 963ms/epoch - 160ms/step
# Epoch 99/1000
# 6/6 - 1s - loss: 0.0119 - 1s/epoch - 169ms/step
# Epoch 100/1000
# 6/6 - 1s - loss: 0.0129 - 1s/epoch - 170ms/step
# Epoch 101/1000
# 6/6 - 1s - loss: 0.0122 - 1s/epoch - 167ms/step
# Epoch 102/1000
# 6/6 - 1s - loss: 0.0120 - 1s/epoch - 169ms/step
# Epoch 103/1000
# 6/6 - 1s - loss: 0.0123 - 1s/epoch - 176ms/step
# Epoch 104/1000
# 6/6 - 1s - loss: 0.0119 - 1s/epoch - 173ms/step
# Epoch 105/1000
# 6/6 - 1s - loss: 0.0114 - 937ms/epoch - 156ms/step
# Epoch 106/1000
# 6/6 - 1s - loss: 0.0114 - 924ms/epoch - 154ms/step
# Epoch 107/1000
# 6/6 - 1s - loss: 0.0113 - 960ms/epoch - 160ms/step
# Epoch 108/1000
# 6/6 - 1s - loss: 0.0115 - 1s/epoch - 176ms/step
# Epoch 109/1000
# 6/6 - 1s - loss: 0.0114 - 1s/epoch - 168ms/step
# Epoch 110/1000
# 6/6 - 1s - loss: 0.0119 - 1s/epoch - 170ms/step
# Epoch 111/1000
# 6/6 - 1s - loss: 0.0125 - 955ms/epoch - 159ms/step
# Epoch 112/1000
# 6/6 - 1s - loss: 0.0134 - 983ms/epoch - 164ms/step
# Epoch 113/1000
# 6/6 - 1s - loss: 0.0114 - 978ms/epoch - 163ms/step
# Epoch 114/1000
# 6/6 - 1s - loss: 0.0108 - 1s/epoch - 169ms/step
# Epoch 115/1000
# 6/6 - 1s - loss: 0.0108 - 966ms/epoch - 161ms/step
# Epoch 116/1000
# 6/6 - 1s - loss: 0.0106 - 1s/epoch - 171ms/step
# Epoch 117/1000
# 6/6 - 1s - loss: 0.0105 - 1s/epoch - 167ms/step
# Epoch 118/1000
# 6/6 - 1s - loss: 0.0108 - 960ms/epoch - 160ms/step
# Epoch 119/1000
# 6/6 - 1s - loss: 0.0107 - 973ms/epoch - 162ms/step
# Epoch 120/1000
# 6/6 - 1s - loss: 0.0102 - 998ms/epoch - 166ms/step
# Epoch 121/1000
# 6/6 - 1s - loss: 0.0101 - 1s/epoch - 169ms/step
# Epoch 122/1000
# 6/6 - 1s - loss: 0.0100 - 1s/epoch - 170ms/step
# Epoch 123/1000
# 6/6 - 1s - loss: 0.0100 - 1s/epoch - 169ms/step
# Epoch 124/1000
# 6/6 - 1s - loss: 0.0100 - 1s/epoch - 169ms/step
# Epoch 125/1000
# 6/6 - 1s - loss: 0.0099 - 1s/epoch - 169ms/step
# Epoch 126/1000
# 6/6 - 1s - loss: 0.0096 - 936ms/epoch - 156ms/step
# Epoch 127/1000
# 6/6 - 1s - loss: 0.0099 - 948ms/epoch - 158ms/step
# Epoch 128/1000
# 6/6 - 1s - loss: 0.0101 - 1s/epoch - 168ms/step
# Epoch 129/1000
# 6/6 - 1s - loss: 0.0101 - 1s/epoch - 167ms/step
# Epoch 130/1000
# 6/6 - 1s - loss: 0.0108 - 999ms/epoch - 167ms/step
# Epoch 131/1000
# 6/6 - 1s - loss: 0.0105 - 1s/epoch - 169ms/step
# Epoch 132/1000
# 6/6 - 1s - loss: 0.0102 - 1s/epoch - 170ms/step
# Epoch 133/1000
# 6/6 - 1s - loss: 0.0100 - 1s/epoch - 172ms/step
# Epoch 134/1000
# 6/6 - 1s - loss: 0.0103 - 987ms/epoch - 165ms/step
# Epoch 135/1000
# 6/6 - 1s - loss: 0.0101 - 1s/epoch - 171ms/step
# Epoch 136/1000
# 6/6 - 1s - loss: 0.0110 - 931ms/epoch - 155ms/step
# Epoch 137/1000
# 6/6 - 1s - loss: 0.0094 - 937ms/epoch - 156ms/step
# Epoch 138/1000
# 6/6 - 1s - loss: 0.0094 - 936ms/epoch - 156ms/step
# Epoch 139/1000
# 6/6 - 1s - loss: 0.0092 - 897ms/epoch - 149ms/step
# Epoch 140/1000
# 6/6 - 1s - loss: 0.0093 - 965ms/epoch - 161ms/step
# Epoch 141/1000
# 6/6 - 1s - loss: 0.0098 - 986ms/epoch - 164ms/step
# Epoch 142/1000
# 6/6 - 1s - loss: 0.0102 - 1s/epoch - 168ms/step
# Epoch 143/1000
# 6/6 - 1s - loss: 0.0102 - 1s/epoch - 170ms/step
# Epoch 144/1000
# 6/6 - 1s - loss: 0.0104 - 974ms/epoch - 162ms/step
# Epoch 145/1000
# 6/6 - 1s - loss: 0.0099 - 932ms/epoch - 155ms/step
# Epoch 146/1000
# 6/6 - 1s - loss: 0.0091 - 958ms/epoch - 160ms/step
# Epoch 147/1000
# 6/6 - 1s - loss: 0.0088 - 1s/epoch - 171ms/step
# Epoch 148/1000
# 6/6 - 1s - loss: 0.0088 - 1s/epoch - 169ms/step
# Epoch 149/1000
# 6/6 - 1s - loss: 0.0090 - 951ms/epoch - 159ms/step
# Epoch 150/1000
# 6/6 - 1s - loss: 0.0094 - 1s/epoch - 168ms/step
# Epoch 151/1000
# 6/6 - 1s - loss: 0.0090 - 1s/epoch - 172ms/step
# Epoch 152/1000
# 6/6 - 1s - loss: 0.0089 - 969ms/epoch - 162ms/step
# Epoch 153/1000
# 6/6 - 1s - loss: 0.0093 - 1s/epoch - 168ms/step
# Epoch 154/1000
# 6/6 - 1s - loss: 0.0086 - 1s/epoch - 172ms/step
# Epoch 155/1000
# 6/6 - 1s - loss: 0.0105 - 1s/epoch - 168ms/step
# Epoch 156/1000
# 6/6 - 1s - loss: 0.0095 - 961ms/epoch - 160ms/step
# Epoch 157/1000
# 6/6 - 1s - loss: 0.0093 - 974ms/epoch - 162ms/step
# Epoch 158/1000
# 6/6 - 1s - loss: 0.0091 - 977ms/epoch - 163ms/step
# Epoch 159/1000
# 6/6 - 1s - loss: 0.0085 - 1s/epoch - 176ms/step
# Epoch 160/1000
# 6/6 - 1s - loss: 0.0087 - 947ms/epoch - 158ms/step
# Epoch 161/1000
# 6/6 - 1s - loss: 0.0084 - 1s/epoch - 167ms/step
# Epoch 162/1000
# 6/6 - 1s - loss: 0.0085 - 1s/epoch - 169ms/step
# Epoch 163/1000
# 6/6 - 1s - loss: 0.0080 - 1s/epoch - 171ms/step
# Epoch 164/1000
# 6/6 - 1s - loss: 0.0080 - 926ms/epoch - 154ms/step
# Epoch 165/1000
# 6/6 - 1s - loss: 0.0080 - 1s/epoch - 175ms/step
# Epoch 166/1000
# 6/6 - 1s - loss: 0.0082 - 1s/epoch - 167ms/step
# Epoch 167/1000
# 6/6 - 1s - loss: 0.0076 - 991ms/epoch - 165ms/step
# Epoch 168/1000
# 6/6 - 1s - loss: 0.0081 - 902ms/epoch - 150ms/step
# Epoch 169/1000
# 6/6 - 1s - loss: 0.0081 - 962ms/epoch - 160ms/step
# Epoch 170/1000
# 6/6 - 1s - loss: 0.0077 - 963ms/epoch - 160ms/step
# Epoch 171/1000
# 6/6 - 1s - loss: 0.0087 - 973ms/epoch - 162ms/step
# Epoch 172/1000
# 6/6 - 1s - loss: 0.0093 - 1s/epoch - 173ms/step
# Epoch 173/1000
# 6/6 - 1s - loss: 0.0084 - 958ms/epoch - 160ms/step
# Epoch 174/1000
# 6/6 - 1s - loss: 0.0088 - 945ms/epoch - 157ms/step
# Epoch 175/1000
# 6/6 - 1s - loss: 0.0082 - 1s/epoch - 179ms/step
# Epoch 176/1000
# 6/6 - 1s - loss: 0.0080 - 946ms/epoch - 158ms/step
# Epoch 177/1000
# 6/6 - 1s - loss: 0.0081 - 1s/epoch - 173ms/step
# Epoch 178/1000
# 6/6 - 1s - loss: 0.0079 - 962ms/epoch - 160ms/step
# Epoch 179/1000
# 6/6 - 1s - loss: 0.0079 - 1s/epoch - 167ms/step
# Epoch 180/1000
# 6/6 - 1s - loss: 0.0079 - 1s/epoch - 168ms/step
# Epoch 181/1000
# 6/6 - 1s - loss: 0.0076 - 1s/epoch - 173ms/step
# Epoch 182/1000
# 6/6 - 1s - loss: 0.0075 - 937ms/epoch - 156ms/step
# Epoch 183/1000
# 6/6 - 1s - loss: 0.0069 - 912ms/epoch - 152ms/step
# Epoch 184/1000
# 6/6 - 1s - loss: 0.0069 - 954ms/epoch - 159ms/step
# Epoch 185/1000
# 6/6 - 1s - loss: 0.0068 - 998ms/epoch - 166ms/step
# Epoch 186/1000
# 6/6 - 1s - loss: 0.0070 - 1s/epoch - 172ms/step
# Epoch 187/1000
# 6/6 - 1s - loss: 0.0074 - 963ms/epoch - 161ms/step
# Epoch 188/1000
# 6/6 - 1s - loss: 0.0074 - 1s/epoch - 173ms/step
# Epoch 189/1000
# 6/6 - 1s - loss: 0.0075 - 1s/epoch - 170ms/step
# Epoch 190/1000
# 6/6 - 1s - loss: 0.0084 - 967ms/epoch - 161ms/step
# Epoch 191/1000
# 6/6 - 1s - loss: 0.0084 - 957ms/epoch - 160ms/step
# Epoch 192/1000
# 6/6 - 1s - loss: 0.0084 - 978ms/epoch - 163ms/step
# Epoch 193/1000
# 6/6 - 1s - loss: 0.0082 - 990ms/epoch - 165ms/step
# Epoch 194/1000
# 6/6 - 1s - loss: 0.0071 - 1s/epoch - 167ms/step
# Epoch 195/1000
# 6/6 - 1s - loss: 0.0070 - 896ms/epoch - 149ms/step
# Epoch 196/1000
# 6/6 - 1s - loss: 0.0068 - 967ms/epoch - 161ms/step
# Epoch 197/1000
# 6/6 - 1s - loss: 0.0066 - 987ms/epoch - 165ms/step
# Epoch 198/1000
# 6/6 - 1s - loss: 0.0071 - 1s/epoch - 170ms/step
# Epoch 199/1000
# 6/6 - 1s - loss: 0.0067 - 969ms/epoch - 161ms/step
# Epoch 200/1000
# 6/6 - 1s - loss: 0.0068 - 1s/epoch - 168ms/step
# Epoch 201/1000
# 6/6 - 1s - loss: 0.0067 - 1s/epoch - 172ms/step
# Epoch 202/1000
# 6/6 - 1s - loss: 0.0067 - 1s/epoch - 170ms/step
# Epoch 203/1000
# 6/6 - 1s - loss: 0.0069 - 941ms/epoch - 157ms/step
# Epoch 204/1000
# 6/6 - 1s - loss: 0.0071 - 1s/epoch - 167ms/step
# Epoch 205/1000
# 6/6 - 1s - loss: 0.0094 - 979ms/epoch - 163ms/step
# Epoch 206/1000
# 6/6 - 1s - loss: 0.0093 - 1s/epoch - 172ms/step
# Epoch 207/1000
# 6/6 - 1s - loss: 0.0094 - 928ms/epoch - 155ms/step
# Epoch 208/1000
# 6/6 - 1s - loss: 0.0086 - 977ms/epoch - 163ms/step
# Epoch 209/1000
# 6/6 - 1s - loss: 0.0093 - 987ms/epoch - 164ms/step
# Epoch 210/1000
# 6/6 - 1s - loss: 0.0077 - 973ms/epoch - 162ms/step
# Epoch 211/1000
# 6/6 - 1s - loss: 0.0068 - 980ms/epoch - 163ms/step
# Epoch 212/1000
# 6/6 - 1s - loss: 0.0072 - 1s/epoch - 169ms/step
# Epoch 213/1000
# 6/6 - 1s - loss: 0.0064 - 1s/epoch - 167ms/step
# Epoch 214/1000
# 6/6 - 1s - loss: 0.0065 - 1s/epoch - 169ms/step
# Epoch 215/1000
# 6/6 - 1s - loss: 0.0079 - 971ms/epoch - 162ms/step
# Epoch 216/1000
# 6/6 - 1s - loss: 0.0070 - 977ms/epoch - 163ms/step
# Epoch 217/1000
# 6/6 - 1s - loss: 0.0067 - 939ms/epoch - 157ms/step
# Epoch 218/1000
# 6/6 - 1s - loss: 0.0061 - 889ms/epoch - 148ms/step
# Epoch 219/1000
# 6/6 - 1s - loss: 0.0067 - 953ms/epoch - 159ms/step
# Epoch 220/1000
# 6/6 - 1s - loss: 0.0067 - 1s/epoch - 173ms/step
# Epoch 221/1000
# 6/6 - 1s - loss: 0.0075 - 996ms/epoch - 166ms/step
# Epoch 222/1000
# 6/6 - 1s - loss: 0.0064 - 975ms/epoch - 162ms/step
# Epoch 223/1000
# 6/6 - 1s - loss: 0.0063 - 970ms/epoch - 162ms/step
# Epoch 224/1000
# 6/6 - 1s - loss: 0.0066 - 984ms/epoch - 164ms/step
# Epoch 225/1000
# 6/6 - 1s - loss: 0.0081 - 957ms/epoch - 159ms/step
# Epoch 226/1000
# 6/6 - 1s - loss: 0.0070 - 971ms/epoch - 162ms/step
# Epoch 227/1000
# 6/6 - 1s - loss: 0.0064 - 1s/epoch - 169ms/step
# Epoch 228/1000
# 6/6 - 1s - loss: 0.0070 - 1s/epoch - 168ms/step
# Epoch 229/1000
# 6/6 - 1s - loss: 0.0063 - 915ms/epoch - 152ms/step
# Epoch 230/1000
# 6/6 - 1s - loss: 0.0069 - 1s/epoch - 169ms/step
# Epoch 231/1000
# 6/6 - 1s - loss: 0.0064 - 1s/epoch - 170ms/step
# Epoch 232/1000
# 6/6 - 1s - loss: 0.0057 - 890ms/epoch - 148ms/step
# Epoch 233/1000
# 6/6 - 1s - loss: 0.0060 - 1s/epoch - 169ms/step
# Epoch 234/1000
# 6/6 - 1s - loss: 0.0056 - 996ms/epoch - 166ms/step
# Epoch 235/1000
# 6/6 - 1s - loss: 0.0054 - 938ms/epoch - 156ms/step
# Epoch 236/1000
# 6/6 - 1s - loss: 0.0054 - 980ms/epoch - 163ms/step
# Epoch 237/1000
# 6/6 - 1s - loss: 0.0054 - 1s/epoch - 174ms/step
# Epoch 238/1000
# 6/6 - 1s - loss: 0.0051 - 960ms/epoch - 160ms/step
# Epoch 239/1000
# 6/6 - 1s - loss: 0.0053 - 941ms/epoch - 157ms/step
# Epoch 240/1000
# 6/6 - 1s - loss: 0.0052 - 998ms/epoch - 166ms/step
# Epoch 241/1000
# 6/6 - 1s - loss: 0.0051 - 995ms/epoch - 166ms/step
# Epoch 242/1000
# 6/6 - 1s - loss: 0.0050 - 1s/epoch - 169ms/step
# Epoch 243/1000
# 6/6 - 1s - loss: 0.0050 - 959ms/epoch - 160ms/step
# Epoch 244/1000
# 6/6 - 1s - loss: 0.0052 - 930ms/epoch - 155ms/step
# Epoch 245/1000
# 6/6 - 1s - loss: 0.0050 - 1s/epoch - 168ms/step
# Epoch 246/1000
# 6/6 - 1s - loss: 0.0051 - 994ms/epoch - 166ms/step
# Epoch 247/1000
# 6/6 - 1s - loss: 0.0050 - 1s/epoch - 168ms/step
# Epoch 248/1000
# 6/6 - 1s - loss: 0.0048 - 1s/epoch - 167ms/step
# Epoch 249/1000
# 6/6 - 1s - loss: 0.0050 - 1s/epoch - 170ms/step
# Epoch 250/1000
# 6/6 - 1s - loss: 0.0055 - 953ms/epoch - 159ms/step
# Epoch 251/1000
# 6/6 - 1s - loss: 0.0060 - 970ms/epoch - 162ms/step
# Epoch 252/1000
# 6/6 - 1s - loss: 0.0071 - 1s/epoch - 168ms/step
# Epoch 253/1000
# 6/6 - 1s - loss: 0.0061 - 988ms/epoch - 165ms/step
# Epoch 254/1000
# 6/6 - 1s - loss: 0.0056 - 1s/epoch - 171ms/step
# Epoch 255/1000
# 6/6 - 1s - loss: 0.0050 - 968ms/epoch - 161ms/step
# Epoch 256/1000
# 6/6 - 1s - loss: 0.0050 - 982ms/epoch - 164ms/step
# Epoch 257/1000
# 6/6 - 1s - loss: 0.0056 - 943ms/epoch - 157ms/step
# Epoch 258/1000
# 6/6 - 1s - loss: 0.0050 - 989ms/epoch - 165ms/step
# Epoch 259/1000
# 6/6 - 1s - loss: 0.0054 - 975ms/epoch - 162ms/step
# Epoch 260/1000
# 6/6 - 1s - loss: 0.0065 - 978ms/epoch - 163ms/step
# Epoch 261/1000
# 6/6 - 1s - loss: 0.0068 - 911ms/epoch - 152ms/step
# Epoch 262/1000
# 6/6 - 1s - loss: 0.0064 - 1s/epoch - 171ms/step
# Epoch 263/1000
# 6/6 - 1s - loss: 0.0065 - 935ms/epoch - 156ms/step
# Epoch 264/1000
# 6/6 - 1s - loss: 0.0055 - 978ms/epoch - 163ms/step
# Epoch 265/1000
# 6/6 - 1s - loss: 0.0051 - 958ms/epoch - 160ms/step
# Epoch 266/1000
# 6/6 - 1s - loss: 0.0060 - 955ms/epoch - 159ms/step
# Epoch 267/1000
# 6/6 - 1s - loss: 0.0055 - 1000ms/epoch - 167ms/step
# Epoch 268/1000
# 6/6 - 1s - loss: 0.0063 - 1s/epoch - 181ms/step
# Epoch 269/1000
# 6/6 - 1s - loss: 0.0050 - 1s/epoch - 170ms/step
# Epoch 270/1000
# 6/6 - 1s - loss: 0.0053 - 927ms/epoch - 155ms/step
# Epoch 271/1000
# 6/6 - 1s - loss: 0.0055 - 969ms/epoch - 161ms/step
# Epoch 272/1000
# 6/6 - 1s - loss: 0.0055 - 973ms/epoch - 162ms/step
# Epoch 273/1000
# 6/6 - 1s - loss: 0.0047 - 971ms/epoch - 162ms/step
# Epoch 274/1000
# 6/6 - 1s - loss: 0.0048 - 942ms/epoch - 157ms/step
# Epoch 275/1000
# 6/6 - 1s - loss: 0.0050 - 959ms/epoch - 160ms/step
# Epoch 276/1000
# 6/6 - 1s - loss: 0.0053 - 1s/epoch - 169ms/step
# Epoch 277/1000
# 6/6 - 1s - loss: 0.0065 - 984ms/epoch - 164ms/step
# Epoch 278/1000
# 6/6 - 1s - loss: 0.0059 - 1s/epoch - 172ms/step
# Epoch 279/1000
# 6/6 - 1s - loss: 0.0052 - 1s/epoch - 167ms/step
# Epoch 280/1000
# 6/6 - 1s - loss: 0.0052 - 984ms/epoch - 164ms/step
# Epoch 281/1000
# 6/6 - 1s - loss: 0.0055 - 961ms/epoch - 160ms/step
# Epoch 282/1000
# 6/6 - 1s - loss: 0.0051 - 1s/epoch - 169ms/step
# Epoch 283/1000
# 6/6 - 1s - loss: 0.0047 - 1s/epoch - 173ms/step
# Epoch 284/1000
# 6/6 - 1s - loss: 0.0046 - 969ms/epoch - 161ms/step
# Epoch 285/1000
# 6/6 - 1s - loss: 0.0049 - 954ms/epoch - 159ms/step
# Epoch 286/1000
# 6/6 - 1s - loss: 0.0044 - 978ms/epoch - 163ms/step
# Epoch 287/1000
# 6/6 - 1s - loss: 0.0044 - 1s/epoch - 167ms/step
# Epoch 288/1000
# 6/6 - 1s - loss: 0.0043 - 932ms/epoch - 155ms/step
# Epoch 289/1000
# 6/6 - 1s - loss: 0.0045 - 1s/epoch - 168ms/step
# Epoch 290/1000
# 6/6 - 1s - loss: 0.0048 - 907ms/epoch - 151ms/step
# Epoch 291/1000
# 6/6 - 1s - loss: 0.0045 - 988ms/epoch - 165ms/step
# Epoch 292/1000
# 6/6 - 1s - loss: 0.0044 - 985ms/epoch - 164ms/step
# Epoch 293/1000
# 6/6 - 1s - loss: 0.0041 - 1s/epoch - 169ms/step
# Epoch 294/1000
# 6/6 - 1s - loss: 0.0041 - 970ms/epoch - 162ms/step
# Epoch 295/1000
# 6/6 - 1s - loss: 0.0041 - 982ms/epoch - 164ms/step
# Epoch 296/1000
# 6/6 - 1s - loss: 0.0039 - 1s/epoch - 170ms/step
# Epoch 297/1000
# 6/6 - 1s - loss: 0.0039 - 1s/epoch - 175ms/step
# Epoch 298/1000
# 6/6 - 1s - loss: 0.0042 - 990ms/epoch - 165ms/step
# Epoch 299/1000
# 6/6 - 1s - loss: 0.0045 - 978ms/epoch - 163ms/step
# Epoch 300/1000
# 6/6 - 1s - loss: 0.0043 - 1s/epoch - 171ms/step
# Epoch 301/1000
# 6/6 - 1s - loss: 0.0045 - 982ms/epoch - 164ms/step
# Epoch 302/1000
# 6/6 - 1s - loss: 0.0048 - 930ms/epoch - 155ms/step
# Epoch 303/1000
# 6/6 - 1s - loss: 0.0064 - 1s/epoch - 171ms/step
# Epoch 304/1000
# 6/6 - 1s - loss: 0.0052 - 998ms/epoch - 166ms/step
# Epoch 305/1000
# 6/6 - 1s - loss: 0.0047 - 1s/epoch - 169ms/step
# Epoch 306/1000
# 6/6 - 1s - loss: 0.0044 - 956ms/epoch - 159ms/step
# Epoch 307/1000
# 6/6 - 1s - loss: 0.0042 - 1s/epoch - 168ms/step
# Epoch 308/1000
# 6/6 - 1s - loss: 0.0044 - 932ms/epoch - 155ms/step
# Epoch 309/1000
# 6/6 - 1s - loss: 0.0040 - 1s/epoch - 167ms/step
# Epoch 310/1000
# 6/6 - 1s - loss: 0.0041 - 970ms/epoch - 162ms/step
# Epoch 311/1000
# 6/6 - 1s - loss: 0.0038 - 952ms/epoch - 159ms/step
# Epoch 312/1000
# 6/6 - 1s - loss: 0.0041 - 940ms/epoch - 157ms/step
# Epoch 313/1000
# 6/6 - 1s - loss: 0.0039 - 976ms/epoch - 163ms/step
# Epoch 314/1000
# 6/6 - 1s - loss: 0.0037 - 1s/epoch - 169ms/step
# Epoch 315/1000
# 6/6 - 1s - loss: 0.0036 - 1s/epoch - 173ms/step
# Epoch 316/1000
# 6/6 - 1s - loss: 0.0044 - 982ms/epoch - 164ms/step
# Epoch 317/1000
# 6/6 - 1s - loss: 0.0052 - 1s/epoch - 169ms/step
# Epoch 318/1000
# 6/6 - 1s - loss: 0.0044 - 935ms/epoch - 156ms/step
# Epoch 319/1000
# 6/6 - 1s - loss: 0.0044 - 1s/epoch - 172ms/step
# Epoch 320/1000
# 6/6 - 1s - loss: 0.0040 - 958ms/epoch - 160ms/step
# Epoch 321/1000
# 6/6 - 1s - loss: 0.0038 - 945ms/epoch - 157ms/step
# Epoch 322/1000
# 6/6 - 1s - loss: 0.0037 - 891ms/epoch - 148ms/step
# Epoch 323/1000
# 6/6 - 1s - loss: 0.0039 - 959ms/epoch - 160ms/step
# Epoch 324/1000
# 6/6 - 1s - loss: 0.0037 - 981ms/epoch - 163ms/step
# Epoch 325/1000
# 6/6 - 1s - loss: 0.0035 - 997ms/epoch - 166ms/step
# Epoch 326/1000
# 6/6 - 1s - loss: 0.0036 - 995ms/epoch - 166ms/step
# Epoch 327/1000
# 6/6 - 1s - loss: 0.0044 - 940ms/epoch - 157ms/step
# Epoch 328/1000
# 6/6 - 1s - loss: 0.0035 - 969ms/epoch - 161ms/step
# Epoch 329/1000
# 6/6 - 1s - loss: 0.0036 - 1s/epoch - 168ms/step
# Epoch 330/1000
# 6/6 - 1s - loss: 0.0035 - 924ms/epoch - 154ms/step
# Epoch 331/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 169ms/step
# Epoch 332/1000
# 6/6 - 1s - loss: 0.0039 - 947ms/epoch - 158ms/step
# Epoch 333/1000
# 6/6 - 1s - loss: 0.0035 - 987ms/epoch - 165ms/step
# Epoch 334/1000
# 6/6 - 1s - loss: 0.0035 - 903ms/epoch - 150ms/step
# Epoch 335/1000
# 6/6 - 1s - loss: 0.0033 - 945ms/epoch - 157ms/step
# Epoch 336/1000
# 6/6 - 1s - loss: 0.0038 - 989ms/epoch - 165ms/step
# Epoch 337/1000
# 6/6 - 1s - loss: 0.0037 - 1s/epoch - 169ms/step
# Epoch 338/1000
# 6/6 - 1s - loss: 0.0038 - 929ms/epoch - 155ms/step
# Epoch 339/1000
# 6/6 - 1s - loss: 0.0046 - 977ms/epoch - 163ms/step
# Epoch 340/1000
# 6/6 - 1s - loss: 0.0065 - 1s/epoch - 172ms/step
# Epoch 341/1000
# 6/6 - 1s - loss: 0.0064 - 931ms/epoch - 155ms/step
# Epoch 342/1000
# 6/6 - 1s - loss: 0.0068 - 996ms/epoch - 166ms/step
# Epoch 343/1000
# 6/6 - 1s - loss: 0.0059 - 930ms/epoch - 155ms/step
# Epoch 344/1000
# 6/6 - 1s - loss: 0.0058 - 1s/epoch - 172ms/step
# Epoch 345/1000
# 6/6 - 1s - loss: 0.0095 - 935ms/epoch - 156ms/step
# Epoch 346/1000
# 6/6 - 1s - loss: 0.0077 - 983ms/epoch - 164ms/step
# Epoch 347/1000
# 6/6 - 1s - loss: 0.0054 - 974ms/epoch - 162ms/step
# Epoch 348/1000
# 6/6 - 1s - loss: 0.0045 - 1s/epoch - 169ms/step
# Epoch 349/1000
# 6/6 - 1s - loss: 0.0039 - 1s/epoch - 170ms/step
# Epoch 350/1000
# 6/6 - 1s - loss: 0.0036 - 1s/epoch - 174ms/step
# Epoch 351/1000
# 6/6 - 1s - loss: 0.0033 - 974ms/epoch - 162ms/step
# Epoch 352/1000
# 6/6 - 1s - loss: 0.0033 - 937ms/epoch - 156ms/step
# Epoch 353/1000
# 6/6 - 1s - loss: 0.0034 - 964ms/epoch - 161ms/step
# Epoch 354/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 167ms/step
# Epoch 355/1000
# 6/6 - 1s - loss: 0.0033 - 904ms/epoch - 151ms/step
# Epoch 356/1000
# 6/6 - 1s - loss: 0.0032 - 908ms/epoch - 151ms/step
# Epoch 357/1000
# 6/6 - 1s - loss: 0.0035 - 930ms/epoch - 155ms/step
# Epoch 358/1000
# 6/6 - 1s - loss: 0.0036 - 919ms/epoch - 153ms/step
# Epoch 359/1000
# 6/6 - 1s - loss: 0.0034 - 1s/epoch - 171ms/step
# Epoch 360/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 168ms/step
# Epoch 361/1000
# 6/6 - 1s - loss: 0.0037 - 1s/epoch - 177ms/step
# Epoch 362/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 173ms/step
# Epoch 363/1000
# 6/6 - 1s - loss: 0.0030 - 970ms/epoch - 162ms/step
# Epoch 364/1000
# 6/6 - 1s - loss: 0.0030 - 1s/epoch - 167ms/step
# Epoch 365/1000
# 6/6 - 1s - loss: 0.0031 - 998ms/epoch - 166ms/step
# Epoch 366/1000
# 6/6 - 1s - loss: 0.0031 - 968ms/epoch - 161ms/step
# Epoch 367/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 169ms/step
# Epoch 368/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 169ms/step
# Epoch 369/1000
# 6/6 - 1s - loss: 0.0035 - 981ms/epoch - 164ms/step
# Epoch 370/1000
# 6/6 - 1s - loss: 0.0036 - 966ms/epoch - 161ms/step
# Epoch 371/1000
# 6/6 - 1s - loss: 0.0034 - 1s/epoch - 172ms/step
# Epoch 372/1000
# 6/6 - 1s - loss: 0.0030 - 978ms/epoch - 163ms/step
# Epoch 373/1000
# 6/6 - 1s - loss: 0.0032 - 910ms/epoch - 152ms/step
# Epoch 374/1000
# 6/6 - 1s - loss: 0.0032 - 978ms/epoch - 163ms/step
# Epoch 375/1000
# 6/6 - 1s - loss: 0.0041 - 954ms/epoch - 159ms/step
# Epoch 376/1000
# 6/6 - 1s - loss: 0.0037 - 928ms/epoch - 155ms/step
# Epoch 377/1000
# 6/6 - 1s - loss: 0.0034 - 1s/epoch - 168ms/step
# Epoch 378/1000
# 6/6 - 1s - loss: 0.0036 - 936ms/epoch - 156ms/step
# Epoch 379/1000
# 6/6 - 1s - loss: 0.0040 - 964ms/epoch - 161ms/step
# Epoch 380/1000
# 6/6 - 1s - loss: 0.0033 - 1s/epoch - 168ms/step
# Epoch 381/1000
# 6/6 - 1s - loss: 0.0037 - 951ms/epoch - 159ms/step
# Epoch 382/1000
# 6/6 - 1s - loss: 0.0042 - 982ms/epoch - 164ms/step
# Epoch 383/1000
# 6/6 - 1s - loss: 0.0043 - 958ms/epoch - 160ms/step
# Epoch 384/1000
# 6/6 - 1s - loss: 0.0051 - 963ms/epoch - 160ms/step
# Epoch 385/1000
# 6/6 - 1s - loss: 0.0063 - 995ms/epoch - 166ms/step
# Epoch 386/1000
# 6/6 - 1s - loss: 0.0050 - 1s/epoch - 169ms/step
# Epoch 387/1000
# 6/6 - 1s - loss: 0.0037 - 1s/epoch - 173ms/step
# Epoch 388/1000
# 6/6 - 1s - loss: 0.0034 - 986ms/epoch - 164ms/step
# Epoch 389/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 171ms/step
# Epoch 390/1000
# 6/6 - 1s - loss: 0.0029 - 888ms/epoch - 148ms/step
# Epoch 391/1000
# 6/6 - 1s - loss: 0.0030 - 985ms/epoch - 164ms/step
# Epoch 392/1000
# 6/6 - 1s - loss: 0.0030 - 964ms/epoch - 161ms/step
# Epoch 393/1000
# 6/6 - 1s - loss: 0.0040 - 967ms/epoch - 161ms/step
# Epoch 394/1000
# 6/6 - 1s - loss: 0.0030 - 995ms/epoch - 166ms/step
# Epoch 395/1000
# 6/6 - 1s - loss: 0.0030 - 956ms/epoch - 159ms/step
# Epoch 396/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 177ms/step
# Epoch 397/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 167ms/step
# Epoch 398/1000
# 6/6 - 1s - loss: 0.0027 - 1s/epoch - 171ms/step
# Epoch 399/1000
# 6/6 - 1s - loss: 0.0028 - 933ms/epoch - 156ms/step
# Epoch 400/1000
# 6/6 - 1s - loss: 0.0027 - 999ms/epoch - 166ms/step
# Epoch 401/1000
# 6/6 - 1s - loss: 0.0028 - 966ms/epoch - 161ms/step
# Epoch 402/1000
# 6/6 - 1s - loss: 0.0030 - 1s/epoch - 168ms/step
# Epoch 403/1000
# 6/6 - 1s - loss: 0.0033 - 986ms/epoch - 164ms/step
# Epoch 404/1000
# 6/6 - 1s - loss: 0.0030 - 925ms/epoch - 154ms/step
# Epoch 405/1000
# 6/6 - 1s - loss: 0.0032 - 980ms/epoch - 163ms/step
# Epoch 406/1000
# 6/6 - 1s - loss: 0.0028 - 993ms/epoch - 165ms/step
# Epoch 407/1000
# 6/6 - 1s - loss: 0.0029 - 981ms/epoch - 163ms/step
# Epoch 408/1000
# 6/6 - 1s - loss: 0.0031 - 1s/epoch - 171ms/step
# Epoch 409/1000
# 6/6 - 1s - loss: 0.0030 - 1s/epoch - 174ms/step
# Epoch 410/1000
# 6/6 - 1s - loss: 0.0030 - 984ms/epoch - 164ms/step
# Epoch 411/1000
# 6/6 - 1s - loss: 0.0027 - 901ms/epoch - 150ms/step
# Epoch 412/1000
# 6/6 - 1s - loss: 0.0030 - 988ms/epoch - 165ms/step
# Epoch 413/1000
# 6/6 - 1s - loss: 0.0033 - 1s/epoch - 175ms/step
# Epoch 414/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 167ms/step
# Epoch 415/1000
# 6/6 - 1s - loss: 0.0027 - 1s/epoch - 172ms/step
# Epoch 416/1000
# 6/6 - 1s - loss: 0.0033 - 984ms/epoch - 164ms/step
# Epoch 417/1000
# 6/6 - 1s - loss: 0.0029 - 1s/epoch - 173ms/step
# Epoch 418/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 171ms/step
# Epoch 419/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 185ms/step
# Epoch 420/1000
# 6/6 - 1s - loss: 0.0031 - 971ms/epoch - 162ms/step
# Epoch 421/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 180ms/step
# Epoch 422/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 175ms/step
# Epoch 423/1000
# 6/6 - 1s - loss: 0.0036 - 1s/epoch - 180ms/step
# Epoch 424/1000
# 6/6 - 1s - loss: 0.0029 - 1s/epoch - 178ms/step
# Epoch 425/1000
# 6/6 - 1s - loss: 0.0027 - 925ms/epoch - 154ms/step
# Epoch 426/1000
# 6/6 - 1s - loss: 0.0034 - 1s/epoch - 168ms/step
# Epoch 427/1000
# 6/6 - 1s - loss: 0.0032 - 955ms/epoch - 159ms/step
# Epoch 428/1000
# 6/6 - 1s - loss: 0.0029 - 1s/epoch - 175ms/step
# Epoch 429/1000
# 6/6 - 1s - loss: 0.0028 - 989ms/epoch - 165ms/step
# Epoch 430/1000
# 6/6 - 1s - loss: 0.0027 - 944ms/epoch - 157ms/step
# Epoch 431/1000
# 6/6 - 1s - loss: 0.0027 - 1s/epoch - 176ms/step
# Epoch 432/1000
# 6/6 - 1s - loss: 0.0029 - 981ms/epoch - 164ms/step
# Epoch 433/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 173ms/step
# Epoch 434/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 169ms/step
# Epoch 435/1000
# 6/6 - 1s - loss: 0.0027 - 947ms/epoch - 158ms/step
# Epoch 436/1000
# 6/6 - 1s - loss: 0.0029 - 1s/epoch - 170ms/step
# Epoch 437/1000
# 6/6 - 1s - loss: 0.0026 - 973ms/epoch - 162ms/step
# Epoch 438/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 170ms/step
# Epoch 439/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 169ms/step
# Epoch 440/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 173ms/step
# Epoch 441/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 170ms/step
# Epoch 442/1000
# 6/6 - 1s - loss: 0.0025 - 966ms/epoch - 161ms/step
# Epoch 443/1000
# 6/6 - 1s - loss: 0.0035 - 917ms/epoch - 153ms/step
# Epoch 444/1000
# 6/6 - 1s - loss: 0.0034 - 1s/epoch - 169ms/step
# Epoch 445/1000
# 6/6 - 1s - loss: 0.0040 - 1s/epoch - 170ms/step
# Epoch 446/1000
# 6/6 - 1s - loss: 0.0031 - 1s/epoch - 171ms/step
# Epoch 447/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 168ms/step
# Epoch 448/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 172ms/step
# Epoch 449/1000
# 6/6 - 1s - loss: 0.0041 - 987ms/epoch - 165ms/step
# Epoch 450/1000
# 6/6 - 1s - loss: 0.0046 - 1s/epoch - 167ms/step
# Epoch 451/1000
# 6/6 - 1s - loss: 0.0048 - 992ms/epoch - 165ms/step
# Epoch 452/1000
# 6/6 - 1s - loss: 0.0043 - 970ms/epoch - 162ms/step
# Epoch 453/1000
# 6/6 - 1s - loss: 0.0037 - 1s/epoch - 169ms/step
# Epoch 454/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 167ms/step
# Epoch 455/1000
# 6/6 - 1s - loss: 0.0039 - 980ms/epoch - 163ms/step
# Epoch 456/1000
# 6/6 - 1s - loss: 0.0032 - 958ms/epoch - 160ms/step
# Epoch 457/1000
# 6/6 - 1s - loss: 0.0033 - 1s/epoch - 167ms/step
# Epoch 458/1000
# 6/6 - 1s - loss: 0.0030 - 977ms/epoch - 163ms/step
# Epoch 459/1000
# 6/6 - 1s - loss: 0.0027 - 1s/epoch - 169ms/step
# Epoch 460/1000
# 6/6 - 1s - loss: 0.0026 - 997ms/epoch - 166ms/step
# Epoch 461/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 169ms/step
# Epoch 462/1000
# 6/6 - 1s - loss: 0.0022 - 903ms/epoch - 150ms/step
# Epoch 463/1000
# 6/6 - 1s - loss: 0.0023 - 991ms/epoch - 165ms/step
# Epoch 464/1000
# 6/6 - 1s - loss: 0.0023 - 989ms/epoch - 165ms/step
# Epoch 465/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 173ms/step
# Epoch 466/1000
# 6/6 - 1s - loss: 0.0027 - 961ms/epoch - 160ms/step
# Epoch 467/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 172ms/step
# Epoch 468/1000
# 6/6 - 1s - loss: 0.0031 - 1s/epoch - 172ms/step
# Epoch 469/1000
# 6/6 - 1s - loss: 0.0027 - 954ms/epoch - 159ms/step
# Epoch 470/1000
# 6/6 - 1s - loss: 0.0029 - 944ms/epoch - 157ms/step
# Epoch 471/1000
# 6/6 - 1s - loss: 0.0027 - 962ms/epoch - 160ms/step
# Epoch 472/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 168ms/step
# Epoch 473/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 170ms/step
# Epoch 474/1000
# 6/6 - 1s - loss: 0.0022 - 1s/epoch - 171ms/step
# Epoch 475/1000
# 6/6 - 1s - loss: 0.0022 - 956ms/epoch - 159ms/step
# Epoch 476/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 168ms/step
# Epoch 477/1000
# 6/6 - 1s - loss: 0.0021 - 938ms/epoch - 156ms/step
# Epoch 478/1000
# 6/6 - 1s - loss: 0.0021 - 965ms/epoch - 161ms/step
# Epoch 479/1000
# 6/6 - 1s - loss: 0.0022 - 1s/epoch - 170ms/step
# Epoch 480/1000
# 6/6 - 1s - loss: 0.0022 - 993ms/epoch - 165ms/step
# Epoch 481/1000
# 6/6 - 1s - loss: 0.0022 - 994ms/epoch - 166ms/step
# Epoch 482/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 171ms/step
# Epoch 483/1000
# 6/6 - 1s - loss: 0.0019 - 932ms/epoch - 155ms/step
# Epoch 484/1000
# 6/6 - 1s - loss: 0.0019 - 961ms/epoch - 160ms/step
# Epoch 485/1000
# 6/6 - 1s - loss: 0.0021 - 962ms/epoch - 160ms/step
# Epoch 486/1000
# 6/6 - 1s - loss: 0.0019 - 989ms/epoch - 165ms/step
# Epoch 487/1000
# 6/6 - 1s - loss: 0.0026 - 991ms/epoch - 165ms/step
# Epoch 488/1000
# 6/6 - 1s - loss: 0.0022 - 914ms/epoch - 152ms/step
# Epoch 489/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 175ms/step
# Epoch 490/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 169ms/step
# Epoch 491/1000
# 6/6 - 1s - loss: 0.0020 - 988ms/epoch - 165ms/step
# Epoch 492/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 172ms/step
# Epoch 493/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 172ms/step
# Epoch 494/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 168ms/step
# Epoch 495/1000
# 6/6 - 1s - loss: 0.0023 - 970ms/epoch - 162ms/step
# Epoch 496/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 168ms/step
# Epoch 497/1000
# 6/6 - 1s - loss: 0.0022 - 1s/epoch - 170ms/step
# Epoch 498/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 171ms/step
# Epoch 499/1000
# 6/6 - 1s - loss: 0.0022 - 992ms/epoch - 165ms/step
# Epoch 500/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 177ms/step
# Epoch 501/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 167ms/step
# Epoch 502/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 170ms/step
# Epoch 503/1000
# 6/6 - 1s - loss: 0.0018 - 944ms/epoch - 157ms/step
# Epoch 504/1000
# 6/6 - 1s - loss: 0.0022 - 1s/epoch - 171ms/step
# Epoch 505/1000
# 6/6 - 1s - loss: 0.0024 - 929ms/epoch - 155ms/step
# Epoch 506/1000
# 6/6 - 1s - loss: 0.0021 - 985ms/epoch - 164ms/step
# Epoch 507/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 174ms/step
# Epoch 508/1000
# 6/6 - 1s - loss: 0.0025 - 993ms/epoch - 166ms/step
# Epoch 509/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 171ms/step
# Epoch 510/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 170ms/step
# Epoch 511/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 167ms/step
# Epoch 512/1000
# 6/6 - 1s - loss: 0.0030 - 1s/epoch - 167ms/step
# Epoch 513/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 169ms/step
# Epoch 514/1000
# 6/6 - 1s - loss: 0.0024 - 993ms/epoch - 165ms/step
# Epoch 515/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 175ms/step
# Epoch 516/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 170ms/step
# Epoch 517/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 170ms/step
# Epoch 518/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 175ms/step
# Epoch 519/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 170ms/step
# Epoch 520/1000
# 6/6 - 1s - loss: 0.0021 - 941ms/epoch - 157ms/step
# Epoch 521/1000
# 6/6 - 1s - loss: 0.0021 - 999ms/epoch - 166ms/step
# Epoch 522/1000
# 6/6 - 1s - loss: 0.0022 - 940ms/epoch - 157ms/step
# Epoch 523/1000
# 6/6 - 1s - loss: 0.0020 - 998ms/epoch - 166ms/step
# Epoch 524/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 167ms/step
# Epoch 525/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 170ms/step
# Epoch 526/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 167ms/step
# Epoch 527/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 169ms/step
# Epoch 528/1000
# 6/6 - 1s - loss: 0.0021 - 976ms/epoch - 163ms/step
# Epoch 529/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 171ms/step
# Epoch 530/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 169ms/step
# Epoch 531/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 172ms/step
# Epoch 532/1000
# 6/6 - 1s - loss: 0.0023 - 988ms/epoch - 165ms/step
# Epoch 533/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 171ms/step
# Epoch 534/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 167ms/step
# Epoch 535/1000
# 6/6 - 1s - loss: 0.0022 - 980ms/epoch - 163ms/step
# Epoch 536/1000
# 6/6 - 1s - loss: 0.0023 - 980ms/epoch - 163ms/step
# Epoch 537/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 169ms/step
# Epoch 538/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 167ms/step
# Epoch 539/1000
# 6/6 - 1s - loss: 0.0024 - 915ms/epoch - 152ms/step
# Epoch 540/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 168ms/step
# Epoch 541/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 169ms/step
# Epoch 542/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 176ms/step
# Epoch 543/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 167ms/step
# Epoch 544/1000
# 6/6 - 1s - loss: 0.0030 - 980ms/epoch - 163ms/step
# Epoch 545/1000
# 6/6 - 1s - loss: 0.0029 - 985ms/epoch - 164ms/step
# Epoch 546/1000
# 6/6 - 1s - loss: 0.0031 - 993ms/epoch - 166ms/step
# Epoch 547/1000
# 6/6 - 1s - loss: 0.0023 - 925ms/epoch - 154ms/step
# Epoch 548/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 169ms/step
# Epoch 549/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 171ms/step
# Epoch 550/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 170ms/step
# Epoch 551/1000
# 6/6 - 1s - loss: 0.0021 - 971ms/epoch - 162ms/step
# Epoch 552/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 171ms/step
# Epoch 553/1000
# 6/6 - 1s - loss: 0.0020 - 933ms/epoch - 156ms/step
# Epoch 554/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 167ms/step
# Epoch 555/1000
# 6/6 - 1s - loss: 0.0021 - 933ms/epoch - 155ms/step
# Epoch 556/1000
# 6/6 - 1s - loss: 0.0017 - 970ms/epoch - 162ms/step
# Epoch 557/1000
# 6/6 - 1s - loss: 0.0017 - 935ms/epoch - 156ms/step
# Epoch 558/1000
# 6/6 - 1s - loss: 0.0017 - 989ms/epoch - 165ms/step
# Epoch 559/1000
# 6/6 - 1s - loss: 0.0016 - 993ms/epoch - 166ms/step
# Epoch 560/1000
# 6/6 - 1s - loss: 0.0016 - 961ms/epoch - 160ms/step
# Epoch 561/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 167ms/step
# Epoch 562/1000
# 6/6 - 1s - loss: 0.0017 - 973ms/epoch - 162ms/step
# Epoch 563/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 170ms/step
# Epoch 564/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 167ms/step
# Epoch 565/1000
# 6/6 - 1s - loss: 0.0020 - 980ms/epoch - 163ms/step
# Epoch 566/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 182ms/step
# Epoch 567/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 172ms/step
# Epoch 568/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 168ms/step
# Epoch 569/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 175ms/step
# Epoch 570/1000
# 6/6 - 1s - loss: 0.0031 - 969ms/epoch - 161ms/step
# Epoch 571/1000
# 6/6 - 1s - loss: 0.0026 - 962ms/epoch - 160ms/step
# Epoch 572/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 169ms/step
# Epoch 573/1000
# 6/6 - 1s - loss: 0.0022 - 972ms/epoch - 162ms/step
# Epoch 574/1000
# 6/6 - 1s - loss: 0.0022 - 1s/epoch - 169ms/step
# Epoch 575/1000
# 6/6 - 1s - loss: 0.0019 - 973ms/epoch - 162ms/step
# Epoch 576/1000
# 6/6 - 1s - loss: 0.0019 - 979ms/epoch - 163ms/step
# Epoch 577/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 169ms/step
# Epoch 578/1000
# 6/6 - 1s - loss: 0.0026 - 994ms/epoch - 166ms/step
# Epoch 579/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 174ms/step
# Epoch 580/1000
# 6/6 - 1s - loss: 0.0024 - 985ms/epoch - 164ms/step
# Epoch 581/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 173ms/step
# Epoch 582/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 167ms/step
# Epoch 583/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 170ms/step
# Epoch 584/1000
# 6/6 - 1s - loss: 0.0024 - 868ms/epoch - 145ms/step
# Epoch 585/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 176ms/step
# Epoch 586/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 169ms/step
# Epoch 587/1000
# 6/6 - 1s - loss: 0.0024 - 997ms/epoch - 166ms/step
# Epoch 588/1000
# 6/6 - 1s - loss: 0.0024 - 960ms/epoch - 160ms/step
# Epoch 589/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 172ms/step
# Epoch 590/1000
# 6/6 - 1s - loss: 0.0040 - 1s/epoch - 171ms/step
# Epoch 591/1000
# 6/6 - 1s - loss: 0.0021 - 997ms/epoch - 166ms/step
# Epoch 592/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 172ms/step
# Epoch 593/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 176ms/step
# Epoch 594/1000
# 6/6 - 1s - loss: 0.0017 - 948ms/epoch - 158ms/step
# Epoch 595/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 171ms/step
# Epoch 596/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 176ms/step
# Epoch 597/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 171ms/step
# Epoch 598/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 175ms/step
# Epoch 599/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 170ms/step
# Epoch 600/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 173ms/step
# Epoch 601/1000
# 6/6 - 1s - loss: 0.0017 - 997ms/epoch - 166ms/step
# Epoch 602/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 176ms/step
# Epoch 603/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 177ms/step
# Epoch 604/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 172ms/step
# Epoch 605/1000
# 6/6 - 1s - loss: 0.0018 - 974ms/epoch - 162ms/step
# Epoch 606/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 172ms/step
# Epoch 607/1000
# 6/6 - 1s - loss: 0.0015 - 946ms/epoch - 158ms/step
# Epoch 608/1000
# 6/6 - 1s - loss: 0.0014 - 983ms/epoch - 164ms/step
# Epoch 609/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 174ms/step
# Epoch 610/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 171ms/step
# Epoch 611/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 168ms/step
# Epoch 612/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 176ms/step
# Epoch 613/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 169ms/step
# Epoch 614/1000
# 6/6 - 1s - loss: 0.0021 - 943ms/epoch - 157ms/step
# Epoch 615/1000
# 6/6 - 1s - loss: 0.0019 - 955ms/epoch - 159ms/step
# Epoch 616/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 172ms/step
# Epoch 617/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 168ms/step
# Epoch 618/1000
# 6/6 - 1s - loss: 0.0017 - 921ms/epoch - 154ms/step
# Epoch 619/1000
# 6/6 - 1s - loss: 0.0015 - 993ms/epoch - 165ms/step
# Epoch 620/1000
# 6/6 - 1s - loss: 0.0019 - 986ms/epoch - 164ms/step
# Epoch 621/1000
# 6/6 - 1s - loss: 0.0020 - 941ms/epoch - 157ms/step
# Epoch 622/1000
# 6/6 - 1s - loss: 0.0024 - 941ms/epoch - 157ms/step
# Epoch 623/1000
# 6/6 - 1s - loss: 0.0024 - 990ms/epoch - 165ms/step
# Epoch 624/1000
# 6/6 - 1s - loss: 0.0024 - 1s/epoch - 170ms/step
# Epoch 625/1000
# 6/6 - 1s - loss: 0.0028 - 989ms/epoch - 165ms/step
# Epoch 626/1000
# 6/6 - 1s - loss: 0.0023 - 981ms/epoch - 164ms/step
# Epoch 627/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 172ms/step
# Epoch 628/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 198ms/step
# Epoch 629/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 172ms/step
# Epoch 630/1000
# 6/6 - 1s - loss: 0.0018 - 970ms/epoch - 162ms/step
# Epoch 631/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 173ms/step
# Epoch 632/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 168ms/step
# Epoch 633/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 175ms/step
# Epoch 634/1000
# 6/6 - 1s - loss: 0.0022 - 995ms/epoch - 166ms/step
# Epoch 635/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 169ms/step
# Epoch 636/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 176ms/step
# Epoch 637/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 168ms/step
# Epoch 638/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 168ms/step
# Epoch 639/1000
# 6/6 - 1s - loss: 0.0017 - 951ms/epoch - 159ms/step
# Epoch 640/1000
# 6/6 - 1s - loss: 0.0018 - 991ms/epoch - 165ms/step
# Epoch 641/1000
# 6/6 - 1s - loss: 0.0020 - 973ms/epoch - 162ms/step
# Epoch 642/1000
# 6/6 - 1s - loss: 0.0019 - 971ms/epoch - 162ms/step
# Epoch 643/1000
# 6/6 - 1s - loss: 0.0022 - 971ms/epoch - 162ms/step
# Epoch 644/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 170ms/step
# Epoch 645/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 170ms/step
# Epoch 646/1000
# 6/6 - 1s - loss: 0.0021 - 959ms/epoch - 160ms/step
# Epoch 647/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 169ms/step
# Epoch 648/1000
# 6/6 - 1s - loss: 0.0016 - 985ms/epoch - 164ms/step
# Epoch 649/1000
# 6/6 - 1s - loss: 0.0015 - 970ms/epoch - 162ms/step
# Epoch 650/1000
# 6/6 - 1s - loss: 0.0015 - 989ms/epoch - 165ms/step
# Epoch 651/1000
# 6/6 - 1s - loss: 0.0015 - 995ms/epoch - 166ms/step
# Epoch 652/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 168ms/step
# Epoch 653/1000
# 6/6 - 1s - loss: 0.0018 - 988ms/epoch - 165ms/step
# Epoch 654/1000
# 6/6 - 1s - loss: 0.0016 - 986ms/epoch - 164ms/step
# Epoch 655/1000
# 6/6 - 1s - loss: 0.0017 - 977ms/epoch - 163ms/step
# Epoch 656/1000
# 6/6 - 1s - loss: 0.0019 - 989ms/epoch - 165ms/step
# Epoch 657/1000
# 6/6 - 1s - loss: 0.0017 - 978ms/epoch - 163ms/step
# Epoch 658/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 169ms/step
# Epoch 659/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 169ms/step
# Epoch 660/1000
# 6/6 - 1s - loss: 0.0015 - 942ms/epoch - 157ms/step
# Epoch 661/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 168ms/step
# Epoch 662/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 169ms/step
# Epoch 663/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 167ms/step
# Epoch 664/1000
# 6/6 - 1s - loss: 0.0018 - 982ms/epoch - 164ms/step
# Epoch 665/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 171ms/step
# Epoch 666/1000
# 6/6 - 1s - loss: 0.0017 - 984ms/epoch - 164ms/step
# Epoch 667/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 169ms/step
# Epoch 668/1000
# 6/6 - 1s - loss: 0.0018 - 964ms/epoch - 161ms/step
# Epoch 669/1000
# 6/6 - 1s - loss: 0.0017 - 976ms/epoch - 163ms/step
# Epoch 670/1000
# 6/6 - 1s - loss: 0.0016 - 989ms/epoch - 165ms/step
# Epoch 671/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 174ms/step
# Epoch 672/1000
# 6/6 - 1s - loss: 0.0024 - 907ms/epoch - 151ms/step
# Epoch 673/1000
# 6/6 - 1s - loss: 0.0016 - 979ms/epoch - 163ms/step
# Epoch 674/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 167ms/step
# Epoch 675/1000
# 6/6 - 1s - loss: 0.0016 - 962ms/epoch - 160ms/step
# Epoch 676/1000
# 6/6 - 1s - loss: 0.0017 - 900ms/epoch - 150ms/step
# Epoch 677/1000
# 6/6 - 1s - loss: 0.0017 - 985ms/epoch - 164ms/step
# Epoch 678/1000
# 6/6 - 1s - loss: 0.0014 - 992ms/epoch - 165ms/step
# Epoch 679/1000
# 6/6 - 1s - loss: 0.0014 - 996ms/epoch - 166ms/step
# Epoch 680/1000
# 6/6 - 1s - loss: 0.0014 - 929ms/epoch - 155ms/step
# Epoch 681/1000
# 6/6 - 1s - loss: 0.0020 - 986ms/epoch - 164ms/step
# Epoch 682/1000
# 6/6 - 1s - loss: 0.0020 - 893ms/epoch - 149ms/step
# Epoch 683/1000
# 6/6 - 1s - loss: 0.0020 - 931ms/epoch - 155ms/step
# Epoch 684/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 170ms/step
# Epoch 685/1000
# 6/6 - 1s - loss: 0.0017 - 978ms/epoch - 163ms/step
# Epoch 686/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 169ms/step
# Epoch 687/1000
# 6/6 - 1s - loss: 0.0015 - 978ms/epoch - 163ms/step
# Epoch 688/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 168ms/step
# Epoch 689/1000
# 6/6 - 1s - loss: 0.0018 - 953ms/epoch - 159ms/step
# Epoch 690/1000
# 6/6 - 1s - loss: 0.0016 - 899ms/epoch - 150ms/step
# Epoch 691/1000
# 6/6 - 1s - loss: 0.0015 - 968ms/epoch - 161ms/step
# Epoch 692/1000
# 6/6 - 1s - loss: 0.0013 - 988ms/epoch - 165ms/step
# Epoch 693/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 169ms/step
# Epoch 694/1000
# 6/6 - 1s - loss: 0.0014 - 966ms/epoch - 161ms/step
# Epoch 695/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 173ms/step
# Epoch 696/1000
# 6/6 - 1s - loss: 0.0019 - 934ms/epoch - 156ms/step
# Epoch 697/1000
# 6/6 - 1s - loss: 0.0017 - 991ms/epoch - 165ms/step
# Epoch 698/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 169ms/step
# Epoch 699/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 168ms/step
# Epoch 700/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 172ms/step
# Epoch 701/1000
# 6/6 - 1s - loss: 0.0042 - 1s/epoch - 172ms/step
# Epoch 702/1000
# 6/6 - 1s - loss: 0.0065 - 1s/epoch - 172ms/step
# Epoch 703/1000
# 6/6 - 1s - loss: 0.0056 - 1s/epoch - 182ms/step
# Epoch 704/1000
# 6/6 - 1s - loss: 0.0040 - 988ms/epoch - 165ms/step
# Epoch 705/1000
# 6/6 - 1s - loss: 0.0035 - 1s/epoch - 169ms/step
# Epoch 706/1000
# 6/6 - 1s - loss: 0.0025 - 1s/epoch - 169ms/step
# Epoch 707/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 170ms/step
# Epoch 708/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 172ms/step
# Epoch 709/1000
# 6/6 - 1s - loss: 0.0024 - 993ms/epoch - 166ms/step
# Epoch 710/1000
# 6/6 - 1s - loss: 0.0022 - 976ms/epoch - 163ms/step
# Epoch 711/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 167ms/step
# Epoch 712/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 173ms/step
# Epoch 713/1000
# 6/6 - 1s - loss: 0.0017 - 984ms/epoch - 164ms/step
# Epoch 714/1000
# 6/6 - 1s - loss: 0.0016 - 1000ms/epoch - 167ms/step
# Epoch 715/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 168ms/step
# Epoch 716/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 168ms/step
# Epoch 717/1000
# 6/6 - 1s - loss: 0.0014 - 997ms/epoch - 166ms/step
# Epoch 718/1000
# 6/6 - 1s - loss: 0.0017 - 966ms/epoch - 161ms/step
# Epoch 719/1000
# 6/6 - 1s - loss: 0.0015 - 978ms/epoch - 163ms/step
# Epoch 720/1000
# 6/6 - 1s - loss: 0.0017 - 989ms/epoch - 165ms/step
# Epoch 721/1000
# 6/6 - 1s - loss: 0.0016 - 923ms/epoch - 154ms/step
# Epoch 722/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 169ms/step
# Epoch 723/1000
# 6/6 - 1s - loss: 0.0014 - 932ms/epoch - 155ms/step
# Epoch 724/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 170ms/step
# Epoch 725/1000
# 6/6 - 1s - loss: 0.0021 - 979ms/epoch - 163ms/step
# Epoch 726/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 172ms/step
# Epoch 727/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 171ms/step
# Epoch 728/1000
# 6/6 - 1s - loss: 0.0018 - 985ms/epoch - 164ms/step
# Epoch 729/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 168ms/step
# Epoch 730/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 168ms/step
# Epoch 731/1000
# 6/6 - 1s - loss: 0.0017 - 904ms/epoch - 151ms/step
# Epoch 732/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 170ms/step
# Epoch 733/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 168ms/step
# Epoch 734/1000
# 6/6 - 1s - loss: 0.0016 - 992ms/epoch - 165ms/step
# Epoch 735/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 171ms/step
# Epoch 736/1000
# 6/6 - 1s - loss: 0.0015 - 940ms/epoch - 157ms/step
# Epoch 737/1000
# 6/6 - 1s - loss: 0.0021 - 966ms/epoch - 161ms/step
# Epoch 738/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 174ms/step
# Epoch 739/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 167ms/step
# Epoch 740/1000
# 6/6 - 1s - loss: 0.0017 - 989ms/epoch - 165ms/step
# Epoch 741/1000
# 6/6 - 1s - loss: 0.0017 - 900ms/epoch - 150ms/step
# Epoch 742/1000
# 6/6 - 1s - loss: 0.0014 - 974ms/epoch - 162ms/step
# Epoch 743/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 168ms/step
# Epoch 744/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 169ms/step
# Epoch 745/1000
# ...
# 6/6 - 1s - loss: 0.0012 - 975ms/epoch - 162ms/step
# Epoch 756/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 171ms/step
# Epoch 757/1000
# 6/6 - 1s - loss: 0.0018 - 952ms/epoch - 159ms/step
# Epoch 758/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 167ms/step
# Epoch 759/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 170ms/step
# Epoch 760/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 167ms/step
# Epoch 761/1000
# 6/6 - 1s - loss: 0.0015 - 943ms/epoch - 157ms/step
# Epoch 762/1000
# 6/6 - 1s - loss: 0.0013 - 950ms/epoch - 158ms/step
# Epoch 763/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 179ms/step
# Epoch 764/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 169ms/step
# Epoch 765/1000
# 6/6 - 1s - loss: 0.0015 - 939ms/epoch - 157ms/step
# Epoch 766/1000
# 6/6 - 1s - loss: 0.0017 - 997ms/epoch - 166ms/step
# Epoch 767/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 172ms/step
# Epoch 768/1000
# 6/6 - 1s - loss: 0.0017 - 959ms/epoch - 160ms/step
# Epoch 769/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 167ms/step
# Epoch 770/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 170ms/step
# Epoch 771/1000
# 6/6 - 1s - loss: 0.0016 - 969ms/epoch - 161ms/step
# Epoch 772/1000
# 6/6 - 1s - loss: 0.0014 - 916ms/epoch - 153ms/step
# Epoch 773/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 178ms/step
# Epoch 774/1000
# 6/6 - 1s - loss: 0.0018 - 968ms/epoch - 161ms/step
# Epoch 775/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 170ms/step
# Epoch 776/1000
# 6/6 - 1s - loss: 0.0022 - 914ms/epoch - 152ms/step
# Epoch 777/1000
# 6/6 - 1s - loss: 0.0023 - 985ms/epoch - 164ms/step
# Epoch 778/1000
# 6/6 - 1s - loss: 0.0020 - 931ms/epoch - 155ms/step
# Epoch 779/1000
# 6/6 - 1s - loss: 0.0026 - 1s/epoch - 167ms/step
# Epoch 780/1000
# 6/6 - 1s - loss: 0.0023 - 921ms/epoch - 153ms/step
# Epoch 781/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 167ms/step
# Epoch 782/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 172ms/step
# Epoch 783/1000
# 6/6 - 1s - loss: 0.0015 - 987ms/epoch - 165ms/step
# Epoch 784/1000
# 6/6 - 1s - loss: 0.0016 - 980ms/epoch - 163ms/step
# Epoch 785/1000
# 6/6 - 1s - loss: 0.0015 - 987ms/epoch - 164ms/step
# Epoch 786/1000
# 6/6 - 1s - loss: 0.0015 - 913ms/epoch - 152ms/step
# Epoch 787/1000
# 6/6 - 1s - loss: 0.0022 - 983ms/epoch - 164ms/step
# Epoch 788/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 170ms/step
# Epoch 789/1000
# 6/6 - 1s - loss: 0.0015 - 980ms/epoch - 163ms/step
# Epoch 790/1000
# 6/6 - 1s - loss: 0.0013 - 947ms/epoch - 158ms/step
# Epoch 791/1000
# 6/6 - 1s - loss: 0.0012 - 996ms/epoch - 166ms/step
# Epoch 792/1000
# 6/6 - 1s - loss: 0.0014 - 968ms/epoch - 161ms/step
# Epoch 793/1000
# 6/6 - 1s - loss: 0.0013 - 1s/epoch - 168ms/step
# Epoch 794/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 168ms/step
# Epoch 795/1000
# 6/6 - 1s - loss: 0.0013 - 945ms/epoch - 157ms/step
# Epoch 796/1000
# 6/6 - 1s - loss: 0.0017 - 964ms/epoch - 161ms/step
# Epoch 797/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 167ms/step
# Epoch 798/1000
# 6/6 - 1s - loss: 0.0017 - 993ms/epoch - 166ms/step
# Epoch 799/1000
# 6/6 - 1s - loss: 0.0015 - 991ms/epoch - 165ms/step
# Epoch 800/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 170ms/step
# Epoch 801/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 170ms/step
# Epoch 802/1000
# 6/6 - 1s - loss: 0.0031 - 968ms/epoch - 161ms/step
# Epoch 803/1000
# 6/6 - 1s - loss: 0.0036 - 1s/epoch - 168ms/step
# Epoch 804/1000
# 6/6 - 1s - loss: 0.0032 - 1s/epoch - 167ms/step
# Epoch 805/1000
# 6/6 - 1s - loss: 0.0037 - 1s/epoch - 168ms/step
# Epoch 806/1000
# 6/6 - 1s - loss: 0.0028 - 1s/epoch - 173ms/step
# Epoch 807/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 173ms/step
# Epoch 808/1000
# 6/6 - 1s - loss: 0.0019 - 975ms/epoch - 163ms/step
# Epoch 809/1000
# 6/6 - 1s - loss: 0.0016 - 995ms/epoch - 166ms/step
# Epoch 810/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 170ms/step
# Epoch 811/1000
# 6/6 - 1s - loss: 0.0014 - 885ms/epoch - 147ms/step
# Epoch 812/1000
# 6/6 - 1s - loss: 0.0014 - 948ms/epoch - 158ms/step
# Epoch 813/1000
# 6/6 - 1s - loss: 0.0017 - 960ms/epoch - 160ms/step
# Epoch 814/1000
# 6/6 - 1s - loss: 0.0017 - 991ms/epoch - 165ms/step
# Epoch 815/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 169ms/step
# Epoch 816/1000
# 6/6 - 1s - loss: 0.0015 - 890ms/epoch - 148ms/step
# Epoch 817/1000
# 6/6 - 1s - loss: 0.0018 - 908ms/epoch - 151ms/step
# Epoch 818/1000
# 6/6 - 1s - loss: 0.0017 - 981ms/epoch - 163ms/step
# Epoch 819/1000
# 6/6 - 1s - loss: 0.0021 - 915ms/epoch - 153ms/step
# Epoch 820/1000
# 6/6 - 1s - loss: 0.0016 - 873ms/epoch - 145ms/step
# Epoch 821/1000
# 6/6 - 1s - loss: 0.0013 - 1s/epoch - 167ms/step
# Epoch 822/1000
# 6/6 - 1s - loss: 0.0012 - 950ms/epoch - 158ms/step
# Epoch 823/1000
# 6/6 - 1s - loss: 0.0012 - 992ms/epoch - 165ms/step
# Epoch 824/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 167ms/step
# Epoch 825/1000
# 6/6 - 1s - loss: 0.0013 - 923ms/epoch - 154ms/step
# Epoch 826/1000
# 6/6 - 1s - loss: 0.0013 - 973ms/epoch - 162ms/step
# Epoch 827/1000
# 6/6 - 1s - loss: 0.0012 - 841ms/epoch - 140ms/step
# Epoch 828/1000
# 6/6 - 1s - loss: 0.0013 - 945ms/epoch - 158ms/step
# Epoch 829/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 167ms/step
# Epoch 830/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 169ms/step
# Epoch 831/1000
# 6/6 - 1s - loss: 0.0014 - 858ms/epoch - 143ms/step
# Epoch 832/1000
# 6/6 - 1s - loss: 0.0013 - 1s/epoch - 174ms/step
# Epoch 833/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 177ms/step
# Epoch 834/1000
# 6/6 - 1s - loss: 0.0015 - 977ms/epoch - 163ms/step
# Epoch 835/1000
# 6/6 - 1s - loss: 0.0018 - 941ms/epoch - 157ms/step
# Epoch 836/1000
# 6/6 - 1s - loss: 0.0014 - 946ms/epoch - 158ms/step
# Epoch 837/1000
# 6/6 - 1s - loss: 0.0017 - 939ms/epoch - 157ms/step
# Epoch 838/1000
# 6/6 - 1s - loss: 0.0018 - 959ms/epoch - 160ms/step
# Epoch 839/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 170ms/step
# Epoch 840/1000
# 6/6 - 1s - loss: 0.0015 - 917ms/epoch - 153ms/step
# Epoch 841/1000
# 6/6 - 1s - loss: 0.0013 - 944ms/epoch - 157ms/step
# Epoch 842/1000
# 6/6 - 1s - loss: 0.0013 - 957ms/epoch - 159ms/step
# Epoch 843/1000
# 6/6 - 1s - loss: 0.0016 - 980ms/epoch - 163ms/step
# Epoch 844/1000
# 6/6 - 1s - loss: 0.0013 - 994ms/epoch - 166ms/step
# Epoch 845/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 171ms/step
# Epoch 846/1000
# 6/6 - 1s - loss: 0.0018 - 982ms/epoch - 164ms/step
# Epoch 847/1000
# 6/6 - 1s - loss: 0.0015 - 968ms/epoch - 161ms/step
# Epoch 848/1000
# 6/6 - 1s - loss: 0.0013 - 977ms/epoch - 163ms/step
# Epoch 849/1000
# 6/6 - 1s - loss: 0.0013 - 951ms/epoch - 158ms/step
# Epoch 850/1000
# 6/6 - 1s - loss: 0.0012 - 998ms/epoch - 166ms/step
# Epoch 851/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 169ms/step
# Epoch 852/1000
# 6/6 - 1s - loss: 0.0014 - 913ms/epoch - 152ms/step
# Epoch 853/1000
# 6/6 - 1s - loss: 0.0015 - 870ms/epoch - 145ms/step
# Epoch 854/1000
# 6/6 - 1s - loss: 0.0017 - 953ms/epoch - 159ms/step
# Epoch 855/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 171ms/step
# Epoch 856/1000
# 6/6 - 1s - loss: 0.0014 - 958ms/epoch - 160ms/step
# Epoch 857/1000
# 6/6 - 1s - loss: 0.0012 - 933ms/epoch - 156ms/step
# Epoch 858/1000
# 6/6 - 1s - loss: 0.0013 - 957ms/epoch - 160ms/step
# Epoch 859/1000
# 6/6 - 1s - loss: 0.0015 - 945ms/epoch - 158ms/step
# Epoch 860/1000
# 6/6 - 1s - loss: 0.0017 - 996ms/epoch - 166ms/step
# Epoch 861/1000
# 6/6 - 1s - loss: 0.0014 - 969ms/epoch - 162ms/step
# Epoch 862/1000
# 6/6 - 1s - loss: 0.0012 - 944ms/epoch - 157ms/step
# Epoch 863/1000
# 6/6 - 1s - loss: 0.0011 - 976ms/epoch - 163ms/step
# Epoch 864/1000
# 6/6 - 1s - loss: 0.0015 - 953ms/epoch - 159ms/step
# Epoch 865/1000
# 6/6 - 1s - loss: 0.0014 - 979ms/epoch - 163ms/step
# Epoch 866/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 167ms/step
# Epoch 867/1000
# 6/6 - 1s - loss: 0.0013 - 952ms/epoch - 159ms/step
# Epoch 868/1000
# 6/6 - 1s - loss: 0.0013 - 963ms/epoch - 160ms/step
# Epoch 869/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 167ms/step
# Epoch 870/1000
# 6/6 - 1s - loss: 0.0011 - 993ms/epoch - 166ms/step
# Epoch 871/1000
# 6/6 - 1s - loss: 0.0012 - 987ms/epoch - 164ms/step
# Epoch 872/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 168ms/step
# Epoch 873/1000
# 6/6 - 1s - loss: 0.0013 - 958ms/epoch - 160ms/step
# Epoch 874/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 170ms/step
# Epoch 875/1000
# 6/6 - 1s - loss: 9.8207e-04 - 1s/epoch - 171ms/step
# Epoch 876/1000
# 6/6 - 1s - loss: 0.0011 - 911ms/epoch - 152ms/step
# Epoch 877/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 168ms/step
# Epoch 878/1000
# 6/6 - 1s - loss: 0.0013 - 972ms/epoch - 162ms/step
# Epoch 879/1000
# 6/6 - 1s - loss: 0.0017 - 962ms/epoch - 160ms/step
# Epoch 880/1000
# 6/6 - 1s - loss: 0.0019 - 979ms/epoch - 163ms/step
# Epoch 881/1000
# 6/6 - 1s - loss: 0.0018 - 913ms/epoch - 152ms/step
# Epoch 882/1000
# 6/6 - 1s - loss: 0.0014 - 984ms/epoch - 164ms/step
# Epoch 883/1000
# 6/6 - 1s - loss: 0.0014 - 995ms/epoch - 166ms/step
# Epoch 884/1000
# 6/6 - 1s - loss: 0.0015 - 969ms/epoch - 162ms/step
# Epoch 885/1000
# 6/6 - 1s - loss: 0.0012 - 990ms/epoch - 165ms/step
# Epoch 886/1000
# 6/6 - 1s - loss: 0.0012 - 965ms/epoch - 161ms/step
# Epoch 887/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 170ms/step
# Epoch 888/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 172ms/step
# Epoch 889/1000
# 6/6 - 1s - loss: 0.0011 - 988ms/epoch - 165ms/step
# Epoch 890/1000
# 6/6 - 1s - loss: 0.0012 - 970ms/epoch - 162ms/step
# Epoch 891/1000
# 6/6 - 1s - loss: 0.0012 - 953ms/epoch - 159ms/step
# Epoch 892/1000
# 6/6 - 1s - loss: 0.0011 - 952ms/epoch - 159ms/step
# Epoch 893/1000
# 6/6 - 1s - loss: 0.0017 - 1s/epoch - 170ms/step
# Epoch 894/1000
# 6/6 - 1s - loss: 0.0024 - 943ms/epoch - 157ms/step
# Epoch 895/1000
# 6/6 - 1s - loss: 0.0026 - 999ms/epoch - 167ms/step
# Epoch 896/1000
# 6/6 - 1s - loss: 0.0020 - 977ms/epoch - 163ms/step
# Epoch 897/1000
# 6/6 - 1s - loss: 0.0024 - 891ms/epoch - 148ms/step
# Epoch 898/1000
# 6/6 - 1s - loss: 0.0018 - 1s/epoch - 167ms/step
# Epoch 899/1000
# 6/6 - 1s - loss: 0.0018 - 969ms/epoch - 162ms/step
# Epoch 900/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 169ms/step
# Epoch 901/1000
# 6/6 - 1s - loss: 0.0020 - 1s/epoch - 170ms/step
# Epoch 902/1000
# 6/6 - 1s - loss: 0.0022 - 1s/epoch - 167ms/step
# Epoch 903/1000
# 6/6 - 1s - loss: 0.0026 - 997ms/epoch - 166ms/step
# Epoch 904/1000
# 6/6 - 1s - loss: 0.0023 - 999ms/epoch - 166ms/step
# Epoch 905/1000
# 6/6 - 1s - loss: 0.0025 - 991ms/epoch - 165ms/step
# Epoch 906/1000
# 6/6 - 1s - loss: 0.0019 - 992ms/epoch - 165ms/step
# Epoch 907/1000
# 6/6 - 1s - loss: 0.0016 - 932ms/epoch - 155ms/step
# Epoch 908/1000
# 6/6 - 1s - loss: 0.0014 - 981ms/epoch - 164ms/step
# Epoch 909/1000
# 6/6 - 1s - loss: 0.0013 - 940ms/epoch - 157ms/step
# Epoch 910/1000
# 6/6 - 1s - loss: 0.0019 - 1s/epoch - 173ms/step
# Epoch 911/1000
# 6/6 - 1s - loss: 0.0016 - 956ms/epoch - 159ms/step
# Epoch 912/1000
# 6/6 - 1s - loss: 0.0014 - 960ms/epoch - 160ms/step
# Epoch 913/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 167ms/step
# Epoch 914/1000
# 6/6 - 1s - loss: 0.0013 - 990ms/epoch - 165ms/step
# Epoch 915/1000
# 6/6 - 1s - loss: 0.0012 - 928ms/epoch - 155ms/step
# Epoch 916/1000
# 6/6 - 1s - loss: 0.0013 - 976ms/epoch - 163ms/step
# Epoch 917/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 170ms/step
# Epoch 918/1000
# 6/6 - 1s - loss: 0.0014 - 971ms/epoch - 162ms/step
# Epoch 919/1000
# 6/6 - 1s - loss: 0.0012 - 946ms/epoch - 158ms/step
# Epoch 920/1000
# 6/6 - 1s - loss: 0.0011 - 975ms/epoch - 163ms/step
# Epoch 921/1000
# 6/6 - 1s - loss: 0.0011 - 920ms/epoch - 153ms/step
# Epoch 922/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 167ms/step
# Epoch 923/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 167ms/step
# Epoch 924/1000
# 6/6 - 1s - loss: 0.0011 - 987ms/epoch - 164ms/step
# Epoch 925/1000
# 6/6 - 1s - loss: 0.0011 - 974ms/epoch - 162ms/step
# Epoch 926/1000
# 6/6 - 1s - loss: 0.0012 - 952ms/epoch - 159ms/step
# Epoch 927/1000
# 6/6 - 1s - loss: 0.0010 - 956ms/epoch - 159ms/step
# Epoch 928/1000
# 6/6 - 1s - loss: 0.0010 - 967ms/epoch - 161ms/step
# Epoch 929/1000
# 6/6 - 1s - loss: 0.0010 - 1s/epoch - 167ms/step
# Epoch 930/1000
# 6/6 - 1s - loss: 0.0011 - 950ms/epoch - 158ms/step
# Epoch 931/1000
# 6/6 - 1s - loss: 0.0014 - 1s/epoch - 177ms/step
# Epoch 932/1000
# 6/6 - 1s - loss: 0.0015 - 994ms/epoch - 166ms/step
# Epoch 933/1000
# 6/6 - 1s - loss: 0.0015 - 974ms/epoch - 162ms/step
# Epoch 934/1000
# 6/6 - 1s - loss: 0.0016 - 958ms/epoch - 160ms/step
# Epoch 935/1000
# 6/6 - 1s - loss: 0.0016 - 910ms/epoch - 152ms/step
# Epoch 936/1000
# 6/6 - 1s - loss: 0.0012 - 973ms/epoch - 162ms/step
# Epoch 937/1000
# 6/6 - 1s - loss: 0.0011 - 909ms/epoch - 151ms/step
# Epoch 938/1000
# 6/6 - 1s - loss: 0.0012 - 961ms/epoch - 160ms/step
# Epoch 939/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 168ms/step
# Epoch 940/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 167ms/step
# Epoch 941/1000
# 6/6 - 1s - loss: 0.0011 - 956ms/epoch - 159ms/step
# Epoch 942/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 168ms/step
# Epoch 943/1000
# 6/6 - 1s - loss: 0.0011 - 883ms/epoch - 147ms/step
# Epoch 944/1000
# 6/6 - 1s - loss: 9.9099e-04 - 1s/epoch - 171ms/step
# Epoch 945/1000
# 6/6 - 1s - loss: 0.0010 - 981ms/epoch - 163ms/step
# Epoch 946/1000
# 6/6 - 1s - loss: 0.0010 - 966ms/epoch - 161ms/step
# Epoch 947/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 171ms/step
# Epoch 948/1000
# 6/6 - 1s - loss: 0.0014 - 967ms/epoch - 161ms/step
# Epoch 949/1000
# 6/6 - 1s - loss: 0.0013 - 1s/epoch - 169ms/step
# Epoch 950/1000
# 6/6 - 1s - loss: 0.0014 - 996ms/epoch - 166ms/step
# Epoch 951/1000
# 6/6 - 1s - loss: 0.0013 - 1s/epoch - 172ms/step
# Epoch 952/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 170ms/step
# Epoch 953/1000
# 6/6 - 1s - loss: 0.0011 - 961ms/epoch - 160ms/step
# Epoch 954/1000
# 6/6 - 1s - loss: 0.0014 - 957ms/epoch - 160ms/step
# Epoch 955/1000
# 6/6 - 1s - loss: 0.0014 - 986ms/epoch - 164ms/step
# Epoch 956/1000
# 6/6 - 1s - loss: 0.0021 - 1s/epoch - 171ms/step
# Epoch 957/1000
# 6/6 - 1s - loss: 0.0015 - 991ms/epoch - 165ms/step
# Epoch 958/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 169ms/step
# Epoch 959/1000
# 6/6 - 1s - loss: 0.0011 - 996ms/epoch - 166ms/step
# Epoch 960/1000
# 6/6 - 1s - loss: 0.0011 - 941ms/epoch - 157ms/step
# Epoch 961/1000
# 6/6 - 1s - loss: 0.0011 - 991ms/epoch - 165ms/step
# Epoch 962/1000
# 6/6 - 1s - loss: 0.0013 - 901ms/epoch - 150ms/step
# Epoch 963/1000
# 6/6 - 1s - loss: 0.0014 - 994ms/epoch - 166ms/step
# Epoch 964/1000
# 6/6 - 1s - loss: 0.0017 - 954ms/epoch - 159ms/step
# Epoch 965/1000
# 6/6 - 1s - loss: 0.0018 - 926ms/epoch - 154ms/step
# Epoch 966/1000
# 6/6 - 1s - loss: 0.0023 - 1s/epoch - 168ms/step
# Epoch 967/1000
# 6/6 - 1s - loss: 0.0015 - 1s/epoch - 169ms/step
# Epoch 968/1000
# 6/6 - 1s - loss: 0.0012 - 985ms/epoch - 164ms/step
# Epoch 969/1000
# 6/6 - 1s - loss: 0.0010 - 985ms/epoch - 164ms/step
# Epoch 970/1000
# 6/6 - 1s - loss: 0.0010 - 956ms/epoch - 159ms/step
# Epoch 971/1000
# 6/6 - 1s - loss: 9.6382e-04 - 992ms/epoch - 165ms/step
# Epoch 972/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 172ms/step
# Epoch 973/1000
# 6/6 - 1s - loss: 0.0012 - 944ms/epoch - 157ms/step
# Epoch 974/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 171ms/step
# Epoch 975/1000
# 6/6 - 1s - loss: 0.0019 - 985ms/epoch - 164ms/step
# Epoch 976/1000
# 6/6 - 1s - loss: 0.0016 - 995ms/epoch - 166ms/step
# Epoch 977/1000
# 6/6 - 1s - loss: 0.0016 - 898ms/epoch - 150ms/step
# Epoch 978/1000
# 6/6 - 1s - loss: 0.0012 - 970ms/epoch - 162ms/step
# Epoch 979/1000
# 6/6 - 1s - loss: 0.0012 - 979ms/epoch - 163ms/step
# Epoch 980/1000
# 6/6 - 1s - loss: 0.0012 - 995ms/epoch - 166ms/step
# Epoch 981/1000
# 6/6 - 1s - loss: 0.0012 - 978ms/epoch - 163ms/step
# Epoch 982/1000
# 6/6 - 1s - loss: 0.0012 - 992ms/epoch - 165ms/step
# Epoch 983/1000
# 6/6 - 1s - loss: 0.0012 - 987ms/epoch - 164ms/step
# Epoch 984/1000
# 6/6 - 1s - loss: 0.0013 - 958ms/epoch - 160ms/step
# Epoch 985/1000
# 6/6 - 1s - loss: 0.0016 - 924ms/epoch - 154ms/step
# Epoch 986/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 169ms/step
# Epoch 987/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 168ms/step
# Epoch 988/1000
# 6/6 - 1s - loss: 0.0014 - 939ms/epoch - 156ms/step
# Epoch 989/1000
# 6/6 - 1s - loss: 0.0013 - 1s/epoch - 170ms/step
# Epoch 990/1000
# 6/6 - 1s - loss: 0.0011 - 931ms/epoch - 155ms/step
# Epoch 991/1000
# 6/6 - 1s - loss: 0.0011 - 1s/epoch - 169ms/step
# Epoch 992/1000
# 6/6 - 1s - loss: 0.0012 - 981ms/epoch - 163ms/step
# Epoch 993/1000
# 6/6 - 1s - loss: 0.0013 - 991ms/epoch - 165ms/step
# Epoch 994/1000
# 6/6 - 1s - loss: 0.0012 - 1s/epoch - 171ms/step
# Epoch 995/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 170ms/step
# Epoch 996/1000
# 6/6 - 1s - loss: 0.0016 - 1s/epoch - 169ms/step
# Epoch 997/1000
# 6/6 - 1s - loss: 0.0016 - 898ms/epoch - 150ms/step
# Epoch 998/1000
# 6/6 - 1s - loss: 0.0022 - 969ms/epoch - 162ms/step
# Epoch 999/1000
# 6/6 - 1s - loss: 0.0018 - 967ms/epoch - 161ms/step
# Epoch 1000/1000
# 6/6 - 1s - loss: 0.0014 - 964ms/epoch - 161ms/step

# %%
#-- Predict the output for test set
x_test_pred = model.predict(x_test, verbose=1)

#-- plot the test results--------------
ind = 0
fig, ax = plt.subplots()

# plt.plot (x_test[ind,:,0], label="Noisy")
plt.plot (x_test_pred[ind,:,0], color='g', linewidth=2,  label="Pred")
# plt.plot (y_test[ind,], color = "orange", linestyle=':', linewidth=1.5,\
#           label="True Ind.")

plt.legend()
plt.xlabel ("Circumferential Locations (Degrees)")
plt.ylabel ("Distance (mm)")
plt.show()
# Out:
# 1/1 [==============================] - 0s 254ms/step

# %%
model_name = "Big_LSTM_Auto_sine.h5"
model.save(model_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20696/1213774138.py in <module>
#       1 model_name = "Big_LSTM_Auto_sine.h5"
# ----> 2 model.save(model_name)
#
# NameError: name 'model' is not defined

# %%
from keras.models import load_model
model_name = "Big_LSTM_Auto_sine.h5"

# %%
#-- Load the model
model = load_model(model_name)
